# %% [markdown]
# ### Análisis de Comentarios de Twitter

# %%
#Mo
# Importamos las librerías

import re
import nltk
import pandas as pd
from datetime import datetime
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from nltk.tokenize import RegexpTokenizer

import gensim
from gensim import corpora
from gensim.models import LdaModel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

###Diccionarios en español para el análisis de polaridad
nltk.download('punkt')
# Tokenización
# Descargar el conjunto de stopwords en español si no lo tienes
nltk.download('stopwords')
# Análisis de polaridad
# Obtención de listado de stopwords del inglés
stop_words = list(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading package punkt to /home/cygnus/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/cygnus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_coments_a = pd.read_csv("twitter_coments_lomeli.csv", usecols=["css-901oao 4"])
df_coments_b = pd.read_csv("twitter_coments_lomeli_3.csv", usecols=["css-901oao 8"])

# Renombramos la columnas

df_coments_a = df_coments_a.rename(columns={"css-901oao 4": "texto"})
df_coments_b = df_coments_b.rename(columns={"css-901oao 8": "texto"})
df_coments = pd.concat([df_coments_a, df_coments_b])
df_coments = df_coments.dropna()
df_coments['texto'] = df_coments['texto'].str.lower()
df_coments.to_csv("coments_x.csv")

# %%
import re

def limpiar_texto(texto):
    # Eliminar caracteres especiales y números
    texto_limpio = re.sub(r'[^\w\sáéíóúüÁÉÍÓÚÜñ]', '', texto, flags=re.UNICODE)
    # Eliminar espacios en blanco adicionales y convertir a minúsculas
    texto_limpio = ' '.join(texto_limpio.split()).lower()
    return texto_limpio

df_coments["texto"] = df_coments["texto"].apply(limpiar_texto)
df_coments['texto'] = df_coments['texto'].str.lower()
tokenizer = RegexpTokenizer(r'\w+')
df_coments['tokens'] = df_coments['texto'].apply(nltk.tokenize.word_tokenize)
df_coments.to_csv("posts_x.csv")
df_coments
# Out:
#                                                  texto  \
# 0                                      la encuestadora
# 1                                    aquí ni pío dicen
# 2                                                    4
# 3    de que sirven la guardia nacional y el ejércit...
# 4    jalisco está con el mejor con el doctor carlos...
# ..                                                 ...
# 538          a él no le toca es regidor en guadalajara
# 539                             mintiendo hasta en eso
# 540  dice desconozco los que las pintaron pero se l...
# 541         entonces usted por su propia mano borrelos
# 542  no junta ni 100 likes en sus post y resulta qu...
#
#                                                 tokens
# 0                                   [la, encuestadora]
# 1                               [aquí, ni, pío, dicen]
# 2                                                  [4]
# 3    [de, que, sirven, la, guardia, nacional, y, el...
# 4    [jalisco, está, con, el, mejor, con, el, docto...
# ..                                                 ...
# 538  [a, él, no, le, toca, es, regidor, en, guadala...
# 539                        [mintiendo, hasta, en, eso]
# 540  [dice, desconozco, los, que, las, pintaron, pe...
# 541  [entonces, usted, por, su, propia, mano, borre...
# 542  [no, junta, ni, 100, likes, en, sus, post, y, ...
#
# [1131 rows x 2 columns]

# %%
# Eliminacion de Stopwords

# Limpieza de Stop_words
stop_words.extend(("q", "d", "van", "si", "pa", "así", "ser", "solo", "tan", "va", "as", "aquí", "hacia","dra", "día","hoy","dd","drcarloslomeli","jajaja"
                "le", "con","ella", "qué", "por", "qu", "ers", "das", "ve", "jajaja", "jeje", "La", "nimo", "ms", "da","doccast","vas","jajajaja",
                "drcarloslomeli", "doc", "dr", "jajajajajajaja"))

##########NUBE DE PALABRAS
def preprocess_text(text):
    words = text # Tokenizar y convertir a minúsculas
    words = [word for word in words if word.isalpha()]  # Eliminar caracteres no alfabéticos
    words = [word for word in words if word not in stop_words]  # Eliminar palabras vacías
    return words


preprocessed_text = df_coments["tokens"].apply(preprocess_text)

preprocessed_text
# Out:
# 0                                         [encuestadora]
# 1                                           [pío, dicen]
# 2                                                     []
# 3      [sirven, guardia, nacional, ejército, sirve, m...
# 4               [jalisco, mejor, doctor, carlos, lomelí]
#                              ...
# 538                         [toca, regidor, guadalajara]
# 539                                          [mintiendo]
# 540       [dice, desconozco, pintaron, agradezco, ánimo]
# 541            [entonces, usted, propia, mano, borrelos]
# 542    [junta, likes, post, resulta, gaste, dinero, b...
# Name: tokens, Length: 1131, dtype: object

# %%
# Unimos todas las listas de palabras en una sola lista
all_words = [word for sublist in preprocessed_text.values for word in sublist]

# Creamos un DataFrame con las palabras y sus frecuencias
word_counts = pd.Series(all_words).value_counts()

# Tomamos las palabras más comunes (puedes ajustar este valor según tus necesidades)
top_words = word_counts.head(10)
top_words.to_csv("top_words_coments.csv")

# %%
import numpy as np
# Unir las palabras en un solo texto (separadas por espacios)
texto = " ".join(all_words)
# Cículo
x, y = np.ogrid[:300, :500]
mask = (x - 150) ** 2 + (y - 250) ** 2 > 230 ** 2
mask = 255 * mask.astype(int)
# Crear el objeto WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white", mask=mask).generate(texto)
# Mostrar la nube de palabras utilizando matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Desactivar ejes
plt.savefig("nube_palabras_coments.png", dpi=300)
plt.show()

# %% [markdown]
# ## Topicos y Temas Emergentes

# %%
import spacy

nlp = spacy.load("es_core_news_sm")

# Función para preprocesar el texto
def preprocess_text(text):
    doc = nlp(text)
    return [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]

# Aplicar el preprocesamiento a cada fila del DataFrame
df_coments['texto_preprocesado'] = df_coments.texto.apply(preprocess_text)
df_coments
# Out:
#                                                  texto  \
# 0                                      la encuestadora
# 1                                    aquí ni pío dicen
# 2                                                    4
# 3    de que sirven la guardia nacional y el ejércit...
# 4    jalisco está con el mejor con el doctor carlos...
# ..                                                 ...
# 538          a él no le toca es regidor en guadalajara
# 539                             mintiendo hasta en eso
# 540  dice desconozco los que las pintaron pero se l...
# 541         entonces usted por su propia mano borrelos
# 542  no junta ni 100 likes en sus post y resulta qu...
#
#                                                 tokens  \
# 0                                   [la, encuestadora]
# 1                               [aquí, ni, pío, dicen]
# 2                                                  [4]
# 3    [de, que, sirven, la, guardia, nacional, y, el...
# 4    [jalisco, está, con, el, mejor, con, el, docto...
# ..                                                 ...
# 538  [a, él, no, le, toca, es, regidor, en, guadala...
# 539                        [mintiendo, hasta, en, eso]
# 540  [dice, desconozco, los, que, las, pintaron, pe...
# 541  [entonces, usted, por, su, propia, mano, borre...
# 542  [no, junta, ni, 100, likes, en, sus, post, y, ...
#
#                                     texto_preprocesado
# 0                                       [encuestadora]
# 1                                                [pío]
# 2                                                   []
# 3    [servir, guardia, nacional, ejército, servir, ...
# 4                    [jalisco, doctor, carlos, lomelí]
# ..                                                 ...
# 538                      [tocar, regidor, guadalajara]
# 539                                           [mentir]
# 540             [desconozco, pintar, agradecer, ánimo]
# 541                                   [mano, borre él]
# 542  [junto, likes, post, resultar, gastar, dinero,...
#
# [1131 rows x 3 columns]

# %%
# Generación de bigramas con spaCy
nlp = spacy.load("es_core_news_sm")

def generar_bigramas_spacy(texto):
    doc = nlp(texto)
    bigramas = [(doc[i].text, doc[i + 1].text) for i in range(len(doc) - 1)]
    return bigramas

df_coments['bigramas_spacy'] = df_coments['texto'].apply(generar_bigramas_spacy)

# %%
from nltk.collocations import *

flatten_corpus = [w for l in df_coments.bigramas_spacy for w in l]

treshold = 3

bigrams = [bigram for bigram in flatten_corpus if len(bigram[0])>treshold and len(bigram[1])>treshold]

# %%
bigram_measure = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_documents(bigrams)
finder.apply_freq_filter(2)
colocaciones = finder.nbest(bigram_measure.pmi, 20)
colocaciones
# Out:
# [('abogada', 'esquivel'),
#  ('alta', 'responsabilidad'),
#  ('alto', 'cargo'),
#  ('arde', 'asta'),
#  ('asiento', 'saber'),
#  ('caro', 'cuernoschuecos'),
#  ('cesar', 'duarte'),
#  ('comas', 'ancias'),
#  ('desafortunado', 'silencio'),
#  ('excelente', 'inicio'),
#  ('frangie', 'artos'),
#  ('fuerzas', 'reales'),
#  ('jajajjaj', 'pelagatos'),
#  ('jarocha', 'pendejø'),
#  ('memes', 'hiram'),
#  ('mexicanos', 'secuestrados'),
#  ('power', 'ranking'),
#  ('prestigio', 'cucharero'),
#  ('quieran', 'pretendan'),
#  ('sector', 'agropecuario')]

# %%
# Función para lematizar el texto
def lematizar_texto(texto):
    doc = nlp(texto)
    lemas = [token.lemma_ for token in doc]
    return " ".join(lemas)

# Aplicar la función de lematización a cada fila del DataFrame
df_coments['texto_lematizado'] = df_coments.texto.apply(lematizar_texto)
df_coments
# Out:
#                                                  texto  \
# 0                                      la encuestadora
# 1                                    aquí ni pío dicen
# 2                                                    4
# 3    de que sirven la guardia nacional y el ejércit...
# 4    jalisco está con el mejor con el doctor carlos...
# ..                                                 ...
# 538          a él no le toca es regidor en guadalajara
# 539                             mintiendo hasta en eso
# 540  dice desconozco los que las pintaron pero se l...
# 541         entonces usted por su propia mano borrelos
# 542  no junta ni 100 likes en sus post y resulta qu...
#
#                                                 tokens  \
# 0                                   [la, encuestadora]
# 1                               [aquí, ni, pío, dicen]
# 2                                                  [4]
# 3    [de, que, sirven, la, guardia, nacional, y, el...
# 4    [jalisco, está, con, el, mejor, con, el, docto...
# ..                                                 ...
# 538  [a, él, no, le, toca, es, regidor, en, guadala...
# 539                        [mintiendo, hasta, en, eso]
# 540  [dice, desconozco, los, que, las, pintaron, pe...
# 541  [entonces, usted, por, su, propia, mano, borre...
# 542  [no, junta, ni, 100, likes, en, sus, post, y, ...
#
#                                     texto_preprocesado  \
# 0                                       [encuestadora]
# 1                                                [pío]
# 2                                                   []
# 3    [servir, guardia, nacional, ejército, servir, ...
# 4                    [jalisco, doctor, carlos, lomelí]
# ..                                                 ...
# 538                      [tocar, regidor, guadalajara]
# 539                                           [mentir]
# 540             [desconozco, pintar, agradecer, ánimo]
# 541                                   [mano, borre él]
# 542  [junto, likes, post, resultar, gastar, dinero,...
#
#                                         bigramas_spacy  \
# 0                                 [(la, encuestadora)]
# 1                [(aquí, ni), (ni, pío), (pío, dicen)]
# 2                                                   []
# 3    [(de, que), (que, sirven), (sirven, la), (la, ...
# 4    [(jalisco, está), (está, con), (con, el), (el,...
# ..                                                 ...
# 538  [(a, él), (él, no), (no, le), (le, toca), (toc...
# 539       [(mintiendo, hasta), (hasta, en), (en, eso)]
# 540  [(dice, desconozco), (desconozco, los), (los, ...
# 541  [(entonces, usted), (usted, por), (por, su), (...
# 542  [(no, junta), (junta, ni), (ni, 100), (100, li...
#
#                                       texto_lematizado
# 0                                      el encuestadora
# 1                                    aquí ni pío decir
# 2                                                    4
# 3    de que servir el guardia nacional y el ejércit...
# 4    jalisco estar con el mejor con el doctor carlo...
# ..                                                 ...
# 538        a él no él tocar ser regidor en guadalajara
# 539                                mentir hasta en ese
# 540  decir desconozco el que él pintar pero él él a...
# 541         entonces usted por su propio mano borre él
# 542  no junto ni 100 likes en su post y resultar qu...
#
# [1131 rows x 5 columns]

# %%
# eliminar la función ner para acelerar el procesamiento
nlp.disable_pipes('ner')

from tqdm import tqdm

# dataset
dataset = df_coments['texto_lematizado']
docs = []
for text in tqdm(nlp.pipe(dataset), total=len(dataset)):
    doc = nlp(text) 
    pt = [token.lemma_.lower() for token in doc if
           (len(token.lemma_) > 1 and token.pos_ == "NOUN" and 
          not token.is_stop)]
    docs.append(pt)

docs
# Out:
# 100%|██████████████████████████████████████| 1131/1131 [00:04<00:00, 231.92it/s]
# [[],
#  ['pío'],
#  [],
#  ['ejército', 'priista'],
#  ['doctor'],
#  ['entrevista'],
#  [],
#  ['juicio', 'ovidio', 'red', 'corrupto'],
#  ['proyecto'],
#  ['año', 'mujer', 'video'],
#  [],
#  [],
#  ['honesto', 'íntegro', 'gracia', 'doc'],
#  ['respeto',
#   'confianza',
#   'persona',
#   'honestidad',
#   'integridad',
#   'labor',
#   'inicio',
#   'semana'],
#  ['respeto',
#   'confianza',
#   'persona',
#   'honestidad',
#   'integridad',
#   'labor',
#   'inicio',
#   'semana'],
#  [],
#  ['ejército'],
#  [],
#  ['objetivo',
#   'dinero',
#   'lugar',
#   'amigo',
#   'negocio',
#   'verificación',
#   'precandidato',
#   'morena'],
#  ['amigo', 'doctor'],
#  ['lana'],
#  ['dr'],
#  ['2024'],
#  [],
#  [],
#  [],
#  ['felicidad', 'suerte', 'gán', 'boca', 'bot'],
#  ['sobreprecio', 'adjudicación'],
#  [],
#  ['semana'],
#  ['cárdena'],
#  ['exacto', 'candidato'],
#  ['soldado', 'transformación', 'jalisco'],
#  ['ejecución'],
#  ['tiempo', 'doctor'],
#  [],
#  ['región'],
#  ['lucha', 'corrupción'],
#  ['horario'],
#  ['liderazgo', 'militante', 'simpatizante'],
#  ['gente', 'apoyo', 'región', 'productivo', 'américa', 'domingo'],
#  ['cara', 'corrupción', 'señor', 'fentanilo'],
#  ['golpe', 'pendejada'],
#  [],
#  ['huevo', 'chorizo'],
#  [],
#  ['don'],
#  ['consultorio'],
#  [],
#  [],
#  ['jajaja'],
#  ['patrimonio'],
#  ['pendejo', 'serio', 'hombre', 'inconformidad', 'deuda'],
#  [],
#  [],
#  ['varón', 'cama', 'esposa'],
#  ['rata'],
#  ['mmada', 'doctor'],
#  ['opción',
#   'escuela',
#   'hermano',
#   'equipo',
#   'suplente',
#   'lemus',
#   'continuidad',
#   'mc'],
#  ['ratero', 'movimiento'],
#  [],
#  ['olor'],
#  ['funcionario', 'candidata', 'municipio', 'oriente'],
#  ['respuesta'],
#  ['gente', 'historia', 'vida'],
#  [],
#  [],
#  ['maestra'],
#  [],
#  ['fentanilo', 'joven'],
#  ['don'],
#  ['movimiento', 'cosa', 'gente', 'conveniencia', 'programa'],
#  ['encuesta', 'zmg', 'interior', 'semana', 'tendencia', 'nombre'],
#  ['apoyo'],
#  ['territorio'],
#  [],
#  ['junta', 'gente', 'perro', 'foto', 'cuat'],
#  ['bendito', 'hija'],
#  ['mc', 'candidato'],
#  [],
#  ['aspirante',
#   'gubernatura',
#   'hombre',
#   'mujer',
#   'encuesta',
#   'candidato',
#   'morena',
#   'gubernatura',
#   'jalisco'],
#  ['pueblo', 'doctor'],
#  ['oriente',
#   'jalisco',
#   'paz',
#   'tranquilidad',
#   'desarrollo',
#   'bienestar',
#   'gracias',
#   'simpatizante',
#   'partido'],
#  [],
#  [],
#  [],
#  ['encuesta'],
#  ['etapa'],
#  [],
#  ['presidente'],
#  ['flor'],
#  ['elección'],
#  ['gracia'],
#  ['hija'],
#  [],
#  ['quiniela'],
#  [],
#  [],
#  ['perfil', 'encuesta'],
#  [],
#  ['jalisco'],
#  ['misterio', 'finalista', 'encuesta'],
#  ['cárdena', 'opción'],
#  [],
#  [],
#  ['cruz', 'política'],
#  ['morena', 'corrupto'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pueblo', 'jalisco', 'doctor'],
#  [],
#  [],
#  [],
#  ['cárdena'],
#  ['encuesta', 'reconocimiento', 'partido', 'puntero'],
#  ['intención', 'compromiso'],
#  ['tiempo', 'campaña'],
#  [],
#  ['saludo', 'dr', 'bolaño', 'apoyo'],
#  ['felicidad', 'pueblo'],
#  ['derrota', 'dinero'],
#  [],
#  ['dedazo'],
#  ['momento', 'oportunidad', 'gente'],
#  ['honor', 'doctor'],
#  ['jajajajajajaja'],
#  ['pinché'],
#  ['precio', 'candidatura', 'morena', 'derrota'],
#  ['mama'],
#  [],
#  [],
#  [],
#  ['cinturincito', 'papá'],
#  [],
#  ['regidor'],
#  ['sondeo', 'reconocimiento'],
#  ['presidiario'],
#  ['mmda', 'doptor'],
#  [],
#  ['candidato'],
#  ['encuesta', 'reconocimiento', 'mario', 'nombre', 'claudia', 'imaginario'],
#  ['habitante', 'zmg'],
#  [],
#  ['chavoruco',
#   'edad',
#   'cabello',
#   'tenis',
#   'puberto',
#   'risa',
#   'serio',
#   'pídale'],
#  ['entrega', 'servicio', 'saludo'],
#  ['territorio'],
#  ['municipio', 'mando', 'jalisco'],
#  [],
#  ['transformación', 'unidad', 'principio'],
#  ['morena', 'descendencia', 'política'],
#  ['proyecto', 'liderazgo'],
#  ['puntero'],
#  [],
#  [],
#  ['dedazo', 'encuesta'],
#  ['perfil'],
#  ['duda', 'claudia', 'mayoría', 'porcentaje', 'claudia'],
#  [],
#  ['malandro'],
#  [],
#  ['claudia'],
#  ['actitud', 'disposición'],
#  [],
#  ['nombre', 'puntero', 'encuesta', 'reconocimiento'],
#  ['doctor', 'morén', 'pueblo', 'jalisco'],
#  ['resultado',
#   'encuesta',
#   'reconocimiento',
#   'aspirante',
#   'coordinación',
#   'comités',
#   'defensa',
#   'jalisco'],
#  ['uña',
#   'nervio',
#   'jalisco',
#   'encuesta',
#   'candidato',
#   'gubernatura',
#   'resignación',
#   'morenista'],
#  ['señor', 'partido', 'tranza'],
#  ['basura', 'morena', 'corrupto'],
#  ['rata'],
#  ['historia'],
#  ['claudia', 'delgadillo', 'morena', 'verde', 'señor', 'contienda'],
#  ['morena', 'cogea', 'corrupto'],
#  [],
#  [],
#  ['ronda', 'miembro'],
#  [],
#  [],
#  [],
#  ['calle', 'empleado', 'mismopasa', 'área'],
#  [],
#  ['dedo'],
#  [],
#  [],
#  ['congruencia', 'dignidad', 'dueño', 'gobernador'],
#  [],
#  ['morenaco'],
#  [],
#  ['apoyo', 'partido', 'compañero'],
#  ['calle', 'presidenta'],
#  [],
#  ['trabajo'],
#  [],
#  ['regidoro'],
#  ['venta', 'honesto', 'encuesta'],
#  ['duda', 'desempeño', 'funcionario', 'atención', 'ciudadanía'],
#  [],
#  ['morena'],
#  ['morenista', 'jalisco', 'naranja', 'pueblo', 'jalisco'],
#  [],
#  ['mato', 'persona', 'restaurante', 'año', 'tradición', 'rafa'],
#  ['película'],
#  [],
#  [],
#  ['violencia'],
#  ['doc',
#   'historia',
#   'empresario',
#   'millonario',
#   'costa',
#   'magnate',
#   'paracetamol',
#   'sobreprecio',
#   'mano'],
#  ['encuesta', 'rumbo', '2024', 'métrica'],
#  [],
#  [],
#  ['semana', 'tema'],
#  ['narco'],
#  [],
#  [],
#  ['octubre', 'borralo', 'chairo', 'importancia'],
#  [],
#  ['colectivo', 'organismo', 'conflicto'],
#  ['semana'],
#  [],
#  ['abrazo', 'bendición'],
#  ['agua'],
#  ['gracias', 'altura', 'esperanza'],
#  ['méxico', 'terreno', 'co', 'pacto'],
#  ['jalisco'],
#  ['perro', 'culpa', 'ala', 'basura'],
#  ['fiesta'],
#  [],
#  ['intención', 'voto'],
#  [],
#  ['objetivo'],
#  [],
#  ['vfg', 'sheinbaum'],
#  ['asco'],
#  [],
#  [],
#  [],
#  ['hombre', 'fresa', 'expriista', 'fraudulenta', 'inmobiliaria'],
#  ['ia'],
#  ['pecho', 'foto', 'masón', 'hermanito'],
#  [],
#  ['milagro', 'chambea', 'venta', 'fentanilo'],
#  ['pedo',
#   'forma',
#   'paso',
#   'año',
#   'riata',
#   'lugar',
#   'oposición',
#   'pelón',
#   'pelón',
#   'aristótel',
#   'falta',
#   'palo',
#   'morena',
#   'muñeco'],
#  ['jalisco', 'mujer'],
#  ['noticia'],
#  [],
#  [],
#  ['ratotaaa'],
#  [],
#  [],
#  ['candidatura', 'luz', 'elección'],
#  [],
#  [],
#  ['número', 'dr', 'movimiento', 'año', 'gente'],
#  ['ratotaaa'],
#  ['bestia', 'elección'],
#  [],
#  ['cárdena', 'galván', 'honesta', 'movimiento', 'política'],
#  ['rata'],
#  [],
#  ['encuesta', 'chupacabras', 'lomeli', 'rata'],
#  [],
#  [],
#  ['innovador', 'gente', 'jalisco'],
#  ['doctor', 'precampaña', 'lástima'],
#  ['mem', 'villanueva', 'morena', 'morén'],
#  ['mem', 'villanueva', 'morena', 'morén'],
#  ['fama', 'rata', '3aunque', 'robatodillo'],
#  ['jajajajajajaja'],
#  [],
#  ['carambo', 'vestidura', 'color'],
#  ['oposición', 'jajaja'],
#  [],
#  [],
#  ['identidad'],
#  ['árbol'],
#  ['sangre'],
#  [],
#  [],
#  ['asesor',
#   'campaña',
#   'proceso',
#   'equipo',
#   'gente',
#   'prepa',
#   'hijo',
#   'politólogo',
#   'experiencia',
#   'palabra',
#   'planeación',
#   'mujer',
#   'pena'],
#  ['imagen', 'telenovela', 'rival'],
#  ['venta', 'medicamento', 'precio'],
#  ['agua', 'bot', 'mc'],
#  ['exacto'],
#  [],
#  ['palabra', 'miedo', 'futuro'],
#  ['dr', 'lobby'],
#  [],
#  [],
#  ['bigotón'],
#  [],
#  ['dr'],
#  ['dinero', 'ayuntamiento', 'gdl', 'precio', 'licitación'],
#  [],
#  ['elección', '2004', 'triunfo', 'mc'],
#  ['perdedor',
#   'alimaña',
#   'historia',
#   'lana',
#   'negocio',
#   'morena',
#   'morena',
#   'memoria'],
#  ['zar', 'medicina', 'gobierno', 'prd', 'morena', 'americano', 'año'],
#  ['candidato', 'tiempo', 'mujer', 'cárdena'],
#  [],
#  ['gente'],
#  ['año', 'elección'],
#  ['encuestadoro', 'ganador', 'marcelo'],
#  ['lomeli', 'candidato', 'dinero'],
#  ['gobernatura', 'idea', 'discurso', 'personaje'],
#  ['lugar'],
#  ['corrupto', 'partido', 'panista', 'priista', 'claudia', 'güero'],
#  ['tiempo', 'definición'],
#  ['pndejazo', 'morén'],
#  ['morena'],
#  [],
#  [],
#  ['sorpré', 'sorpresa', 'claudia'],
#  ['doctor'],
#  ['tonto', 'candidato'],
#  [],
#  ['doctor'],
#  ['plazo',
#   'coordinador',
#   'defensa',
#   'tendencia',
#   'jalisco',
#   'militancia',
#   'simpatizante',
#   'morena'],
#  ['tranza', 'empresa', 'negro', 'jajajajajajajajajajajaja'],
#  ['líder', 'corrupto', 'gente', 'apoyo'],
#  [],
#  ['colo', 'muuuy', 'cof', 'cof'],
#  ['callate'],
#  ['historia', 'recordártelo'],
#  ['jajaja', 'jale', 'contrato', 'empresa', 'cabrón', 'rata', 'movimiento'],
#  [],
#  ['ratota',
#   'candidato',
#   'pelón',
#   'alfaro',
#   'cabrón',
#   'año',
#   'elección',
#   'partido'],
#  ['banqueta', 'pendejada', 'ciudadano', 'cara', 'pendejo', 'oposición'],
#  ['fechoría', 'solución', 'favor'],
#  ['puebla', 'mier', 'equipo', 'fuchi'],
#  ['ridiculo'],
#  ['copia', 'gobierno'],
#  ['tlajomulco', 'juárez', 'asco', 'movimiento', 'cambio'],
#  [],
#  ['catering', 'joya', 'proveedor'],
#  ['cdmx', 'ruta', 'procedimiento', 'sobrerepresentación'],
#  ['momento',
#   'agradecerl',
#   'corazón',
#   'palabra',
#   'comentario',
#   'alentador',
#   'motor',
#   'fuente',
#   'inspiración'],
#  ['martinez'],
#  [],
#  ['regidor'],
#  [],
#  [],
#  ['top'],
#  [],
#  ['lobby', 'depo'],
#  ['saludo'],
#  ['afuero', 'presidencia'],
#  ['lugar'],
#  [],
#  ['denuncia'],
#  [],
#  ['caravana', 'sombrero'],
#  ['prian', 'mes'],
#  [],
#  ['fentanilo'],
#  ['prueba', 'cambio', 'señor'],
#  ['doctor', 'par', 'méndigo'],
#  ['hipocrita'],
#  [],
#  ['evento',
#   'vip',
#   'banquete',
#   'tiempo',
#   'bebida',
#   'mes',
#   'año',
#   'millón',
#   'pesos',
#   'trabajador'],
#  ['hueso', 'tipo'],
#  ['dato'],
#  ['solano'],
#  ['prueba', 'prueba', 'teatro'],
#  ['huevón'],
#  ['cdmx'],
#  ['morena', 'elsalto', 'cosa', 'dinero'],
#  [],
#  ['candidato', 'pese', 'cdmx'],
#  [],
#  ['asesoria', 'banquetes', 'pesos'],
#  [],
#  ['circula', 'red'],
#  ['dinero'],
#  [],
#  [],
#  ['nivel', 'gobierno'],
#  ['hueso'],
#  [],
#  [],
#  ['ánimo', 'transformación'],
#  ['cambio', 'deber'],
#  [],
#  ['modos', 'gracia', 'monto', 'médico', 'preocupación'],
#  ['lamebota'],
#  ['voto', 'frangie', 'ciudadanía', 'cosa', 'corruptela'],
#  [],
#  [],
#  ['tema'],
#  [],
#  [],
#  [],
#  ['pelagato', 'chayote', 'yolanda'],
#  [],
#  ['conferencia', 'prensa', 'administración', 'gobierno'],
#  ['chayote'],
#  ['dispendio', 'millonario'],
#  ['posibilidad', 'año', 'totalidad', 'distrito', 'municipio'],
#  ['regreso', 'gente', 'conciencia', 'regreso', 'corrupcion', 'prian'],
#  ['bandera'],
#  [],
#  [],
#  [],
#  ['dictadura', 'preferido', 'presidente'],
#  ['narco', 'corrupto'],
#  ['cuerno'],
#  [],
#  [],
#  ['teibolera'],
#  [],
#  ['power', 'ranking', 'jalisco', 'lugar', 'alcalde'],
#  [],
#  [],
#  ['boot', 'favor', 'voto'],
#  [],
#  ['forma', 'pena'],
#  ['cama'],
#  ['hombre', 'mujer', 'cárdena'],
#  ['persona', 'cambio', 'jalisco', 'presidente', 'ala', 'saludo'],
#  ['opción'],
#  [],
#  [],
#  ['chemo', 'gente', 'barrio'],
#  ['mensaje', 'sheinbaum'],
#  ['opción', 'jalisco'],
#  [],
#  [],
#  [],
#  ['morena'],
#  ['voto'],
#  ['1351'],
#  [],
#  [],
#  [],
#  ['candidato', 'morena', 'jalisco', 'victoria'],
#  [],
#  ['opción'],
#  ['partido', 'credibilidad', 'comentarista'],
#  [],
#  ['gobernador', 'jalisco'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['chema'],
#  ['deber', 'candidata', 'dedazo', 'policia'],
#  [],
#  ['semana', 'política', 'show', 'dignidad'],
#  ['opcion'],
#  ['amigo', 'narco'],
#  ['pndejo', 'chayotero'],
#  ['chemo', 'opción', 'chema', 'pueblo', 'calidad', 'vida', 'ciudadano'],
#  ['cuerno', 'momia', 'jajajaja'],
#  ['canijo', 'mc', 'candidato'],
#  ['análisis'],
#  ['comentario', 'puntero', 'bot'],
#  ['líder'],
#  ['liderazgo', 'amor'],
#  ['cambio'],
#  [],
#  ['cambio', 'mano'],
#  ['proceso'],
#  [],
#  ['varón', 'cama', 'caro'],
#  ['semana', 'liderazgo', 'amor', 'domingo'],
#  ['medicina', 'tierra'],
#  [],
#  ['jalisco', 'diferenciaclar'],
#  [],
#  ['chema'],
#  ['chayote', 'alta'],
#  [],
#  ['chema', 'gallo'],
#  ['texto'],
#  [],
#  ['análisis', 'sesgo', 'chayote', 'ine'],
#  ['cárdena'],
#  ['flor'],
#  [],
#  [],
#  ['daño'],
#  ['chema'],
#  ['nachito', 'suerte'],
#  [],
#  ['conocimiento', 'chemo'],
#  ['nacho', 'ooh'],
#  ['cálmate', 'cargo', 'ancia'],
#  [],
#  ['ves'],
#  ['cardena'],
#  ['puebla', 'deber'],
#  [],
#  ['dr', 'tienado', 'dinero', 'campaña', 'alcadia', 'llenar', 'propaganda'],
#  ['olovooooorgo'],
#  [],
#  ['julio', 'primo', 'mier', 'equipo'],
#  ['ruta'],
#  ['negocio'],
#  ['ruta'],
#  [],
#  ['ine', 'conque'],
#  ['chinches'],
#  ['chema', 'gobernador'],
#  ['gobernador'],
#  [],
#  ['pena'],
#  ['julio', 'primo', 'pie', 'amlo', 'prd', 'recurso', 'campaña'],
#  [],
#  ['julio', 'primo', 'barboza'],
#  [],
#  ['lic'],
#  ['detalle'],
#  ['negocio', 'fentanilo'],
#  ['narcopolicía'],
#  [],
#  [],
#  ['cinturón'],
#  ['alianza', 'alianza', 'candidata'],
#  [],
#  ['oir'],
#  ['jer'],
#  [],
#  [],
#  ['dato'],
#  [],
#  ['representante', 'raíz', 'trayectoria', 'base'],
#  ['apoyo'],
#  [],
#  [],
#  ['jarocha', 'madre'],
#  ['partido', 'embajador', 'año'],
#  [],
#  ['encuesta', 'interior', 'morena'],
#  [],
#  ['mujer'],
#  ['chema', 'duda'],
#  [],
#  [],
#  ['varón', 'tabasco', 'esposa', 'salchicha'],
#  [],
#  [],
#  ['cobarde', 'secuestrado', 'silencio', 'secta', 'morena', 'asco'],
#  ['ecuación'],
#  ['respuesta', 'jalisco'],
#  ['ine',
#   'orden',
#   'deber',
#   'mujer',
#   'facultad',
#   'echo',
#   'democracia',
#   'pueblo',
#   'deber',
#   'género',
#   'política',
#   'género',
#   'capacidad',
#   'liderazgo',
#   'hombre',
#   'mujer'],
#  [],
#  [],
#  ['evento', 'líder', 'metro', 'líder'],
#  ['opción'],
#  ['deseir',
#   'piso',
#   'berrinche',
#   'niño',
#   'supermercado',
#   'busca',
#   'dulce',
#   'fuerza',
#   'ine'],
#  ['mira'],
#  [],
#  ['gobernador', 'panista', 'morenista', 'traición', 'morena', 'coahuila'],
#  ['deber', 'presidenta'],
#  ['respuesta'],
#  [],
#  ['tesis', 'abogada', 'copia', 'vergüenza', 'favor', 'leerte'],
#  [],
#  ['prestigio'],
#  ['osea', 'presidenta', 'chayote', 'fuerza', 'zapato'],
#  ['aprendiz', 'policía', 'mayoría'],
#  ['criterio'],
#  ['tiempo', 'mujer', 'jalisco'],
#  [],
#  [],
#  ['puente', 'plata'],
#  ['amañado',
#   'comentario',
#   'mayoría',
#   'resultado',
#   'modos',
#   'voto',
#   'comentario'],
#  ['respuesta'],
#  [],
#  ['transformación'],
#  [],
#  ['chema'],
#  ['cariño', 'agradecimiento', 'empresa'],
#  [],
#  [],
#  ['voto', 'cárdena', 'ruta'],
#  ['candidato', 'candidata', 'gubernatura', 'morena', 'cárdena'],
#  ['jajaja'],
#  [],
#  ['señora', 'chiste'],
#  ['seguro', 'anormal'],
#  [],
#  ['lord', 'eschaira'],
#  [],
#  [],
#  ['felicidad', 'dinero', 'erario', 'hipocresía'],
#  [],
#  ['corrupto'],
#  ['candidato'],
#  ['honor'],
#  ['negocio', 'perdón', 'repetición'],
#  ['rémora', 'coneate'],
#  ['chapulín', 'jalisco'],
#  ['par', 'lacra'],
#  [],
#  ['sector'],
#  ['jalisco'],
#  ['hora', 'date'],
#  ['jalsico'],
#  [],
#  [],
#  ['muestra', 'cariño', 'palabra', 'aliento'],
#  ['asiento', 'gobernador'],
#  ['bello', 'imagen'],
#  [],
#  ['par', 'corrupto'],
#  [],
#  [],
#  ['comentario', 'negociazo', 'marrano', 'verficadora', 'multa', 'goleada'],
#  ['agua'],
#  ['año', 'campaña'],
#  ['seguro'],
#  ['paso'],
#  ['exacto'],
#  [],
#  [],
#  ['sujeto', 'candidato', 'gobernador', 'sospecha', 'negocio', 'medicina'],
#  ['gobernador'],
#  ['amiga', 'mujer', 'responsabilidad', 'dra'],
#  ['claudia',
#   'deber',
#   'paso',
#   'candidato',
#   'gobernador',
#   'mc',
#   'candidato',
#   'nexo',
#   'foto',
#   'cárcel',
#   'venta',
#   'medicina'],
#  [],
#  ['jalisco', 'apoyo', 'doctora', 'doctor'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  [],
#  ['fuerza'],
#  ['equipo', 'transformación', 'jalisco'],
#  [],
#  ['territorio'],
#  [],
#  ['nivel', 'gobierno'],
#  ['hueso'],
#  [],
#  [],
#  ['ánimo', 'transformación'],
#  ['cambio', 'deber'],
#  ['modos', 'gracia', 'monto', 'médico', 'preocupación'],
#  ['lamebota'],
#  ['voto', 'frangie', 'ciudadanía', 'cosa', 'corruptela'],
#  [],
#  ['tema'],
#  [],
#  [],
#  ['pelagato', 'chayote', 'yolanda'],
#  [],
#  ['conferencia', 'prensa', 'administración', 'gobierno'],
#  ['chayote'],
#  ['dispendio', 'millonario'],
#  ['posibilidad', 'año', 'totalidad', 'distrito', 'municipio'],
#  ['regreso', 'gente', 'conciencia', 'regreso', 'corrupcion', 'prian'],
#  ['bandera'],
#  [],
#  ['2549'],
#  [],
#  ['dictadura', 'preferido', 'presidente'],
#  [],
#  ['power', 'ranking', 'jalisco', 'lugar', 'alcalde'],
#  [],
#  [],
#  ['boot', 'favor', 'voto'],
#  [],
#  ['forma', 'pena'],
#  ['cama'],
#  ['hombre', 'mujer', 'cárdena'],
#  ['persona', 'cambio', 'jalisco', 'presidente', 'ala', 'saludo'],
#  ['opción'],
#  ['7704'],
#  [],
#  ['chemo', 'gente', 'barrio'],
#  ['mensaje', 'sheinbaum'],
#  ['opción', 'jalisco'],
#  [],
#  [],
#  ['morena'],
#  ['voto'],
#  [],
#  [],
#  [],
#  ['candidato', 'morena', 'jalisco', 'victoria'],
#  [],
#  ['opción'],
#  ['partido', 'credibilidad', 'comentarista'],
#  [],
#  ['gobernador', 'jalisco'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['chema'],
#  ['deber', 'candidata', 'dedazo', 'policia'],
#  ['semana', 'política', 'show', 'dignidad'],
#  ['opcion'],
#  ['amigo', 'narco'],
#  ['pndejo', 'chayotero'],
#  ['chemo', 'opción', 'chema', 'pueblo', 'calidad', 'vida', 'ciudadano'],
#  ['cuerno', 'momia', 'jajajaja'],
#  ['canijo', 'mc', 'candidato'],
#  ['análisis'],
#  ['comentario', 'puntero', 'bot'],
#  ['líder'],
#  ['liderazgo', 'amor'],
#  ['cambio'],
#  ['cambio', 'mano'],
#  ['proceso'],
#  [],
#  ['varón', 'cama', 'caro'],
#  ['semana', 'liderazgo', 'amor', 'domingo'],
#  ['medicina', 'tierra'],
#  ['jalisco', 'diferenciaclar'],
#  [],
#  ['chema'],
#  ['chayote', 'alta'],
#  [],
#  ['chema', 'gallo'],
#  ['texto'],
#  [],
#  ['análisis', 'sesgo', 'chayote', 'ine'],
#  ['cárdena'],
#  ['flor'],
#  [],
#  [],
#  [],
#  ['daño'],
#  ['chema'],
#  ['nachito', 'suerte'],
#  ['conocimiento', 'chemo'],
#  ['nacho', 'ooh'],
#  ['cálmate', 'cargo', 'ancia'],
#  [],
#  ['ves'],
#  ['cardena'],
#  ['puebla', 'deber'],
#  [],
#  ['dr', 'tienado', 'dinero', 'campaña', 'alcadia', 'llenar', 'propaganda'],
#  ['olovooooorgo'],
#  ['julio', 'primo', 'mier', 'equipo'],
#  ['ruta'],
#  ['negocio'],
#  ['ruta'],
#  [],
#  ['ine', 'conque'],
#  ['chinches'],
#  ['chema', 'gobernador'],
#  ['gobernador'],
#  [],
#  ['pena'],
#  ['julio', 'primo', 'pie', 'amlo', 'prd', 'recurso', 'campaña'],
#  [],
#  ['julio', 'primo', 'barboza'],
#  ['lic'],
#  ['detalle'],
#  ['negocio', 'fentanilo'],
#  ['narcopolicía'],
#  [],
#  ['cinturón'],
#  ['alianza', 'alianza', 'candidata'],
#  ['oir'],
#  ['jer'],
#  [],
#  [],
#  ['dato'],
#  [],
#  ['representante', 'raíz', 'trayectoria', 'base'],
#  ['apoyo'],
#  [],
#  [],
#  ['jarocha', 'madre'],
#  ['partido', 'embajador', 'año'],
#  [],
#  ['encuesta', 'interior', 'morena'],
#  [],
#  ['mujer'],
#  ['chema', 'duda'],
#  [],
#  [],
#  ['varón', 'tabasco', 'esposa', 'salchicha'],
#  [],
#  [],
#  ['cobarde', 'secuestrado', 'silencio', 'secta', 'morena', 'asco'],
#  ['ecuación'],
#  ['respuesta', 'jalisco'],
#  ['ine',
#   'orden',
#   'deber',
#   'mujer',
#   'facultad',
#   'echo',
#   'democracia',
#   'pueblo',
#   'deber',
#   'género',
#   'política',
#   'género',
#   'capacidad',
#   'liderazgo',
#   'hombre',
#   'mujer'],
#  [],
#  ['evento', 'líder', 'metro', 'líder'],
#  ['opción'],
#  ['deseir',
#   'piso',
#   'berrinche',
#   'niño',
#   'supermercado',
#   'busca',
#   'dulce',
#   'fuerza',
#   'ine'],
#  ['mira'],
#  ['gobernador', 'panista', 'morenista', 'traición', 'morena', 'coahuila'],
#  ['deber', 'presidenta'],
#  ['respuesta'],
#  [],
#  ['tesis', 'abogada', 'copia', 'vergüenza', 'favor', 'leerte'],
#  ['mira'],
#  ['prestigio'],
#  ['osea', 'presidenta', 'chayote', 'fuerza', 'zapato'],
#  [],
#  ['aprendiz', 'policía', 'mayoría'],
#  ['criterio'],
#  ['tiempo', 'mujer', 'jalisco'],
#  [],
#  ['puente', 'plata'],
#  ['amañado',
#   'comentario',
#   'mayoría',
#   'resultado',
#   'modos',
#   'voto',
#   'comentario'],
#  ['respuesta'],
#  ['transformación'],
#  [],
#  ['chema'],
#  ['cariño', 'agradecimiento', 'empresa'],
#  [],
#  [],
#  ['voto', 'cárdena', 'ruta'],
#  ['candidato', 'candidata', 'gubernatura', 'morena', 'cárdena'],
#  ['jajaja'],
#  ['1171'],
#  ['señora', 'chiste'],
#  ['seguro', 'anormal'],
#  [],
#  ['lord', 'eschaira'],
#  [],
#  ['felicidad', 'dinero', 'erario', 'hipocresía'],
#  [],
#  ['corrupto'],
#  ['candidato'],
#  ['honor'],
#  ['negocio', 'perdón', 'repetición'],
#  ['rémora', 'coneate'],
#  ['chapulín', 'jalisco'],
#  ['par', 'lacra'],
#  ['1110'],
#  ['sector'],
#  ['jalisco'],
#  ['hora', 'date'],
#  ['jalsico'],
#  [],
#  [],
#  ['muestra', 'cariño', 'palabra', 'aliento'],
#  ['asiento', 'gobernador'],
#  ['bello', 'imagen'],
#  ['par', 'corrupto'],
#  [],
#  [],
#  ['comentario', 'negociazo', 'marrano', 'verficadora', 'multa', 'goleada'],
#  ['agua'],
#  ['año', 'campaña'],
#  ['seguro'],
#  ['paso'],
#  ['exacto'],
#  [],
#  [],
#  ['sujeto', 'candidato', 'gobernador', 'sospecha', 'negocio', 'medicina'],
#  ['gobernador'],
#  ['amiga', 'mujer', 'responsabilidad', 'dra'],
#  ['claudia',
#   'deber',
#   'paso',
#   'candidato',
#   'gobernador',
#   'mc',
#   'candidato',
#   'nexo',
#   'foto',
#   'cárcel',
#   'venta',
#   'medicina'],
#  [],
#  ['jalisco', 'apoyo', 'doctora', 'doctor'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  [],
#  ['fuerza'],
#  ['equipo', 'transformación', 'jalisco'],
#  [],
#  ['territorio'],
#  [],
#  ['jalisco', 'gente', 'maltrato'],
#  ['chinch'],
#  [],
#  ['conocimiento', 'duda', 'inseguridad', 'problemática'],
#  ['asesinato', 'narco'],
#  [],
#  ['falta', 'bax'],
#  ['rincón',
#   'orgullo',
#   'oficio',
#   'vocación',
#   'jalisciens',
#   'problema',
#   'habrás',
#   'gobernador',
#   'abrazo'],
#  ['trabajo', 'experiencia'],
#  ['político',
#   'pena',
#   'dinero',
#   'gente',
#   'represente',
#   'proyecto',
#   'amlo',
#   'diputación',
#   'candidatura',
#   'presidencia',
#   'gobernador'],
#  ['esposa',
#   'hija',
#   'bendición',
#   'rincón',
#   'jalisco',
#   'comunidad',
#   'amiga',
#   'amigo',
#   'regalo'],
#  ['fortuna'],
#  [],
#  ['doctor',
#   'acarreo',
#   'manipulación',
#   'funcionario',
#   'gobierno',
#   'trabajo',
#   'paradójico',
#   'administración',
#   'morenista'],
#  ['honor', 'doctor'],
#  ['sirviendote',
#   'comunidad',
#   'gracias',
#   'dinero',
#   'pueblo',
#   'sobreprecio',
#   'medicina',
#   'imss'],
#  ['deseo', 'gracia', 'preocupación'],
#  ['gusto',
#   'momento',
#   'vecino',
#   'tonalá',
#   'deseo',
#   'comités',
#   'defensa',
#   'transformación',
#   'jalisco',
#   'jalisco'],
#  ['medicamento', 'mesa', 'año', 'década', 'obsesión'],
#  ['denuncia', 'amparo', 'despilfarro', 'cintura', 'cantero', 'lelus'],
#  ['señor'],
#  ['honestidad', 'septiembre'],
#  [],
#  ['gente', 'campaña', 'candidato', 'elección', 'equipo', 'pendejo', 'traidor'],
#  ['ok', 'lista', 'elección'],
#  ['democracia',
#   'lugar',
#   'jallisco',
#   'crimen',
#   'deber',
#   'pueblo',
#   'aceptación',
#   'gobernarno',
#   'horizontalidad',
#   'ego',
#   'capital'],
#  ['candidato', 'jalisco'],
#  ['pueblo'],
#  ['comentario', 'red', 'gente', 'recorrido', 'camino', 'vida', 'compromiso'],
#  [],
#  ['mensaje'],
#  ['gobernador', 'jalisco'],
#  [],
#  [],
#  ['servicio', 'cárcel'],
#  ['vida', 'comunidad'],
#  ['encuesta'],
#  [],
#  ['jajaja',
#   'maquillaje',
#   'edición',
#   'evento',
#   'reflector',
#   'sueter',
#   'cuello',
#   'tortuga'],
#  ['comunidad',
#   'perdón',
#   'medicamento',
#   'tratamiento',
#   'cáncer',
#   'gente',
#   'praton',
#   'ayuda'],
#  ['mujer',
#   'libertad',
#   'grito',
#   'cárcel',
#   'narges',
#   'activista',
#   'premio',
#   'paz',
#   'mujer',
#   'víctima',
#   'violencia',
#   'indiferencia',
#   'gobierno',
#   'clamor'],
#  [],
#  ['falla', 'coraje'],
#  [],
#  ['ratero', 'morena', 'jalisco', 'tipo', 'alcalde'],
#  ['quitar'],
#  [],
#  ['guanjo', 'cochinada'],
#  [],
#  ['menso'],
#  ['barda'],
#  ['mandoel', 'año', 'talv'],
#  ['vida', 'comunidad', 'chiste'],
#  ['distrito', 'jalisco', 'impunidad', 'naranja', 'dinero'],
#  [],
#  ['vida',
#   'comunidad',
#   'distrito',
#   'visita',
#   'trabajo',
#   'mano',
#   'joven',
#   'líder',
#   'carencia',
#   'conciencia',
#   'corazón'],
#  [],
#  ['jajaja', 'pendejo'],
#  [],
#  [],
#  [],
#  ['dr', 'gobernador', 'jalisco', 'apoyo', 'dr'],
#  ['edificio', 'propiedad'],
#  [],
#  ['gobernador', 'jalisco'],
#  ['cambio', 'dr', 'apoyo'],
#  ['dr'],
#  ['mano', 'dr'],
#  ['cosa', 'lame', 'huevo', 'jajajaaja'],
#  ['corrupto'],
#  ['candidato',
#   'partido',
#   'cosa',
#   'aspirante',
#   'pensión',
#   'oro',
#   'candidato',
#   'gobernador'],
#  ['mujer', 'jalisco', 'dignidad', 'sueño', 'realidad'],
#  [],
#  ['candidato', 'morena', 'jalisco', 'interés', 'peña'],
#  ['cuéntano', 'perro'],
#  ['2012', '2015', '2018', '2021'],
#  ['2012', 'año'],
#  ['pendejo',
#   'victoria',
#   'pelón',
#   'alfaroi',
#   'lemus',
#   'banda',
#   'lemus',
#   'kgada',
#   'candidato',
#   'morén'],
#  [],
#  ['propiedad'],
#  ['transa', 'empresa', 'gracia', 'preocupación'],
#  [],
#  ['mamada', 'jalisco', 'oportunidad'],
#  ['año',
#   'interés',
#   'pie',
#   'lucha',
#   'hueso',
#   'aspiración',
#   'motor',
#   'desesperanza'],
#  [],
#  ['duda', 'pueblo', 'jalisco'],
#  ['candidato'],
#  [],
#  [],
#  ['vocero'],
#  [],
#  [],
#  [],
#  ['suela', 'pueblo'],
#  ['edificio', 'desmadre', 'amigo', 'narco'],
#  ['objetivo', 'coordinador', 'defensa', 'transformación', 'jalisco'],
#  ['apoyo'],
#  ['encuesta', 'partido', 'ley', 'candidato', 'puesto', 'elección', 'señor'],
#  ['gente', 'gracias', 'cercanía', 'dr'],
#  ['honor',
#   'diálogo',
#   'militante',
#   'simpatizante',
#   'morena',
#   'teuchitlán',
#   'reunión',
#   'compromiso',
#   'transformación',
#   'motivo',
#   'comités',
#   'defensa'],
#  ['gobernador', 'jalisco'],
#  ['miércoles'],
#  ['mujer', 'garra', 'debenso'],
#  ['doña', 'asesinato', 'lobby'],
#  ['matador'],
#  ['ojo', 'edificio'],
#  [],
#  ['hombre', 'edificio'],
#  ['asesinato', 'hombre', 'edificio'],
#  ['matador'],
#  ['respuesta'],
#  ['6337'],
#  ['respuesta'],
#  ['respuesta'],
#  ['edificio'],
#  [],
#  [],
#  ['sobreprecio'],
#  ['perseverancia', 'trabajo', 'sueño'],
#  ['mc'],
#  ['dinero', 'honestidad'],
#  ['presidente', 'militar', 'culpa', 'estudiante'],
#  ['morena', 'piedra', 'mano'],
#  [],
#  ['poniente', 'ciudad', 'avenida', 'zalate', 'pandilla', 'necesitar'],
#  ['paz', 'prosperidad', 'vida'],
#  ['administración', 'compitio'],
#  ['carisma'],
#  ['nombramiento', 'chayote', 'oro'],
#  ['mensaje', 'lona', 'apoyo', 'persona', 'duda'],
#  ['serio'],
#  ['sur'],
#  [],
#  ...]

# %%
from collections import Counter
from itertools import chain

counts_word_occurence = Counter(chain(*[x for x in docs]))

# Palabras con una sola ocurrencia
low_freq_words = {key:value for (key,value) in counts_word_occurence.items() if value==1}
docs = [[lemma for lemma in text if counts_word_occurence[lemma]>0] for text in docs]

# %%
docs_length=len(docs)
# calculate in how many documents a word appeared
counts_word_percentage = Counter(chain(*[set(x) for x in docs]))

# calculate in what % of all articles a word appears
counts_word_percentage = {key:(value/docs_length)*100 for (key,value) in counts_word_percentage.items()}
high_freq_words = {key:value for (key,value) in counts_word_percentage.items() if value>1}

high_freq_words
# Out:
# {'doctor': 1.5915119363395225,
#  'corrupto': 1.6799292661361624,
#  'mujer': 1.5915119363395225,
#  'año': 1.5915119363395225,
#  'dinero': 1.5915119363395225,
#  'lugar': 1.237842617152962,
#  'morena': 3.6251105216622457,
#  'dr': 1.237842617152962,
#  'cárdena': 1.1494252873563218,
#  'candidato': 2.9177718832891246,
#  'jalisco': 5.039787798408488,
#  'apoyo': 1.414677276746242,
#  'gente': 2.033598585322723,
#  'jajaja': 1.1494252873563218,
#  'opción': 1.0610079575596816,
#  'mc': 1.0610079575596816,
#  'encuesta': 1.6799292661361624,
#  'pueblo': 1.5030946065428823,
#  'partido': 1.3262599469496021,
#  'campaña': 1.237842617152962,
#  'gobernador': 2.2104332449160036,
#  'deber': 1.1494252873563218,
#  'chema': 1.414677276746242}

# %%
import pprint

pp = pprint.PrettyPrinter(compact=True)
pp.pprint(docs)
# Out:
# [[], ['pío'], [], ['ejército', 'priista'], ['doctor'], ['entrevista'], [],
#  ['juicio', 'ovidio', 'red', 'corrupto'], ['proyecto'],
#  ['año', 'mujer', 'video'], [], [], ['honesto', 'íntegro', 'gracia', 'doc'],
#  ['respeto', 'confianza', 'persona', 'honestidad', 'integridad', 'labor',
#   'inicio', 'semana'],
#  ['respeto', 'confianza', 'persona', 'honestidad', 'integridad', 'labor',
#   'inicio', 'semana'],
#  [], ['ejército'], [],
#  ['objetivo', 'dinero', 'lugar', 'amigo', 'negocio', 'verificación',
#   'precandidato', 'morena'],
#  ['amigo', 'doctor'], ['lana'], ['dr'], ['2024'], [], [], [],
#  ['felicidad', 'suerte', 'gán', 'boca', 'bot'], ['sobreprecio', 'adjudicación'],
#  [], ['semana'], ['cárdena'], ['exacto', 'candidato'],
#  ['soldado', 'transformación', 'jalisco'], ['ejecución'], ['tiempo', 'doctor'],
#  [], ['región'], ['lucha', 'corrupción'], ['horario'],
#  ['liderazgo', 'militante', 'simpatizante'],
#  ['gente', 'apoyo', 'región', 'productivo', 'américa', 'domingo'],
#  ['cara', 'corrupción', 'señor', 'fentanilo'], ['golpe', 'pendejada'], [],
#  ['huevo', 'chorizo'], [], ['don'], ['consultorio'], [], [], ['jajaja'],
#  ['patrimonio'], ['pendejo', 'serio', 'hombre', 'inconformidad', 'deuda'], [],
#  [], ['varón', 'cama', 'esposa'], ['rata'], ['mmada', 'doctor'],
#  ['opción', 'escuela', 'hermano', 'equipo', 'suplente', 'lemus', 'continuidad',
#   'mc'],
#  ['ratero', 'movimiento'], [], ['olor'],
#  ['funcionario', 'candidata', 'municipio', 'oriente'], ['respuesta'],
#  ['gente', 'historia', 'vida'], [], [], ['maestra'], [], ['fentanilo', 'joven'],
#  ['don'], ['movimiento', 'cosa', 'gente', 'conveniencia', 'programa'],
#  ['encuesta', 'zmg', 'interior', 'semana', 'tendencia', 'nombre'], ['apoyo'],
#  ['territorio'], [], ['junta', 'gente', 'perro', 'foto', 'cuat'],
#  ['bendito', 'hija'], ['mc', 'candidato'], [],
#  ['aspirante', 'gubernatura', 'hombre', 'mujer', 'encuesta', 'candidato',
#   'morena', 'gubernatura', 'jalisco'],
#  ['pueblo', 'doctor'],
#  ['oriente', 'jalisco', 'paz', 'tranquilidad', 'desarrollo', 'bienestar',
#   'gracias', 'simpatizante', 'partido'],
#  [], [], [], ['encuesta'], ['etapa'], [], ['presidente'], ['flor'],
#  ['elección'], ['gracia'], ['hija'], [], ['quiniela'], [], [],
#  ['perfil', 'encuesta'], [], ['jalisco'], ['misterio', 'finalista', 'encuesta'],
#  ['cárdena', 'opción'], [], [], ['cruz', 'política'], ['morena', 'corrupto'],
#  [], [], [], [], [], ['pueblo', 'jalisco', 'doctor'], [], [], [], ['cárdena'],
#  ['encuesta', 'reconocimiento', 'partido', 'puntero'],
#  ['intención', 'compromiso'], ['tiempo', 'campaña'], [],
#  ['saludo', 'dr', 'bolaño', 'apoyo'], ['felicidad', 'pueblo'],
#  ['derrota', 'dinero'], [], ['dedazo'], ['momento', 'oportunidad', 'gente'],
#  ['honor', 'doctor'], ['jajajajajajaja'], ['pinché'],
#  ['precio', 'candidatura', 'morena', 'derrota'], ['mama'], [], [], [],
#  ['cinturincito', 'papá'], [], ['regidor'], ['sondeo', 'reconocimiento'],
#  ['presidiario'], ['mmda', 'doptor'], [], ['candidato'],
#  ['encuesta', 'reconocimiento', 'mario', 'nombre', 'claudia', 'imaginario'],
#  ['habitante', 'zmg'], [],
#  ['chavoruco', 'edad', 'cabello', 'tenis', 'puberto', 'risa', 'serio',
#   'pídale'],
#  ['entrega', 'servicio', 'saludo'], ['territorio'],
#  ['municipio', 'mando', 'jalisco'], [],
#  ['transformación', 'unidad', 'principio'],
#  ['morena', 'descendencia', 'política'], ['proyecto', 'liderazgo'], ['puntero'],
#  [], [], ['dedazo', 'encuesta'], ['perfil'],
#  ['duda', 'claudia', 'mayoría', 'porcentaje', 'claudia'], [], ['malandro'], [],
#  ['claudia'], ['actitud', 'disposición'], [],
#  ['nombre', 'puntero', 'encuesta', 'reconocimiento'],
#  ['doctor', 'morén', 'pueblo', 'jalisco'],
#  ['resultado', 'encuesta', 'reconocimiento', 'aspirante', 'coordinación',
#   'comités', 'defensa', 'jalisco'],
#  ['uña', 'nervio', 'jalisco', 'encuesta', 'candidato', 'gubernatura',
#   'resignación', 'morenista'],
#  ['señor', 'partido', 'tranza'], ['basura', 'morena', 'corrupto'], ['rata'],
#  ['historia'],
#  ['claudia', 'delgadillo', 'morena', 'verde', 'señor', 'contienda'],
#  ['morena', 'cogea', 'corrupto'], [], [], ['ronda', 'miembro'], [], [], [],
#  ['calle', 'empleado', 'mismopasa', 'área'], [], ['dedo'], [], [],
#  ['congruencia', 'dignidad', 'dueño', 'gobernador'], [], ['morenaco'], [],
#  ['apoyo', 'partido', 'compañero'], ['calle', 'presidenta'], [], ['trabajo'],
#  [], ['regidoro'], ['venta', 'honesto', 'encuesta'],
#  ['duda', 'desempeño', 'funcionario', 'atención', 'ciudadanía'], [], ['morena'],
#  ['morenista', 'jalisco', 'naranja', 'pueblo', 'jalisco'], [],
#  ['mato', 'persona', 'restaurante', 'año', 'tradición', 'rafa'], ['película'],
#  [], [], ['violencia'],
#  ['doc', 'historia', 'empresario', 'millonario', 'costa', 'magnate',
#   'paracetamol', 'sobreprecio', 'mano'],
#  ['encuesta', 'rumbo', '2024', 'métrica'], [], [], ['semana', 'tema'],
#  ['narco'], [], [], ['octubre', 'borralo', 'chairo', 'importancia'], [],
#  ['colectivo', 'organismo', 'conflicto'], ['semana'], [],
#  ['abrazo', 'bendición'], ['agua'], ['gracias', 'altura', 'esperanza'],
#  ['méxico', 'terreno', 'co', 'pacto'], ['jalisco'],
#  ['perro', 'culpa', 'ala', 'basura'], ['fiesta'], [], ['intención', 'voto'], [],
#  ['objetivo'], [], ['vfg', 'sheinbaum'], ['asco'], [], [], [],
#  ['hombre', 'fresa', 'expriista', 'fraudulenta', 'inmobiliaria'], ['ia'],
#  ['pecho', 'foto', 'masón', 'hermanito'], [],
#  ['milagro', 'chambea', 'venta', 'fentanilo'],
#  ['pedo', 'forma', 'paso', 'año', 'riata', 'lugar', 'oposición', 'pelón',
#   'pelón', 'aristótel', 'falta', 'palo', 'morena', 'muñeco'],
#  ['jalisco', 'mujer'], ['noticia'], [], [], ['ratotaaa'], [], [],
#  ['candidatura', 'luz', 'elección'], [], [],
#  ['número', 'dr', 'movimiento', 'año', 'gente'], ['ratotaaa'],
#  ['bestia', 'elección'], [],
#  ['cárdena', 'galván', 'honesta', 'movimiento', 'política'], ['rata'], [],
#  ['encuesta', 'chupacabras', 'lomeli', 'rata'], [], [],
#  ['innovador', 'gente', 'jalisco'], ['doctor', 'precampaña', 'lástima'],
#  ['mem', 'villanueva', 'morena', 'morén'],
#  ['mem', 'villanueva', 'morena', 'morén'],
#  ['fama', 'rata', '3aunque', 'robatodillo'], ['jajajajajajaja'], [],
#  ['carambo', 'vestidura', 'color'], ['oposición', 'jajaja'], [], [],
#  ['identidad'], ['árbol'], ['sangre'], [], [],
#  ['asesor', 'campaña', 'proceso', 'equipo', 'gente', 'prepa', 'hijo',
#   'politólogo', 'experiencia', 'palabra', 'planeación', 'mujer', 'pena'],
#  ['imagen', 'telenovela', 'rival'], ['venta', 'medicamento', 'precio'],
#  ['agua', 'bot', 'mc'], ['exacto'], [], ['palabra', 'miedo', 'futuro'],
#  ['dr', 'lobby'], [], [], ['bigotón'], [], ['dr'],
#  ['dinero', 'ayuntamiento', 'gdl', 'precio', 'licitación'], [],
#  ['elección', '2004', 'triunfo', 'mc'],
#  ['perdedor', 'alimaña', 'historia', 'lana', 'negocio', 'morena', 'morena',
#   'memoria'],
#  ['zar', 'medicina', 'gobierno', 'prd', 'morena', 'americano', 'año'],
#  ['candidato', 'tiempo', 'mujer', 'cárdena'], [], ['gente'],
#  ['año', 'elección'], ['encuestadoro', 'ganador', 'marcelo'],
#  ['lomeli', 'candidato', 'dinero'],
#  ['gobernatura', 'idea', 'discurso', 'personaje'], ['lugar'],
#  ['corrupto', 'partido', 'panista', 'priista', 'claudia', 'güero'],
#  ['tiempo', 'definición'], ['pndejazo', 'morén'], ['morena'], [], [],
#  ['sorpré', 'sorpresa', 'claudia'], ['doctor'], ['tonto', 'candidato'], [],
#  ['doctor'],
#  ['plazo', 'coordinador', 'defensa', 'tendencia', 'jalisco', 'militancia',
#   'simpatizante', 'morena'],
#  ['tranza', 'empresa', 'negro', 'jajajajajajajajajajajaja'],
#  ['líder', 'corrupto', 'gente', 'apoyo'], [], ['colo', 'muuuy', 'cof', 'cof'],
#  ['callate'], ['historia', 'recordártelo'],
#  ['jajaja', 'jale', 'contrato', 'empresa', 'cabrón', 'rata', 'movimiento'], [],
#  ['ratota', 'candidato', 'pelón', 'alfaro', 'cabrón', 'año', 'elección',
#   'partido'],
#  ['banqueta', 'pendejada', 'ciudadano', 'cara', 'pendejo', 'oposición'],
#  ['fechoría', 'solución', 'favor'], ['puebla', 'mier', 'equipo', 'fuchi'],
#  ['ridiculo'], ['copia', 'gobierno'],
#  ['tlajomulco', 'juárez', 'asco', 'movimiento', 'cambio'], [],
#  ['catering', 'joya', 'proveedor'],
#  ['cdmx', 'ruta', 'procedimiento', 'sobrerepresentación'],
#  ['momento', 'agradecerl', 'corazón', 'palabra', 'comentario', 'alentador',
#   'motor', 'fuente', 'inspiración'],
#  ['martinez'], [], ['regidor'], [], [], ['top'], [], ['lobby', 'depo'],
#  ['saludo'], ['afuero', 'presidencia'], ['lugar'], [], ['denuncia'], [],
#  ['caravana', 'sombrero'], ['prian', 'mes'], [], ['fentanilo'],
#  ['prueba', 'cambio', 'señor'], ['doctor', 'par', 'méndigo'], ['hipocrita'], [],
#  ['evento', 'vip', 'banquete', 'tiempo', 'bebida', 'mes', 'año', 'millón',
#   'pesos', 'trabajador'],
#  ['hueso', 'tipo'], ['dato'], ['solano'], ['prueba', 'prueba', 'teatro'],
#  ['huevón'], ['cdmx'], ['morena', 'elsalto', 'cosa', 'dinero'], [],
#  ['candidato', 'pese', 'cdmx'], [], ['asesoria', 'banquetes', 'pesos'], [],
#  ['circula', 'red'], ['dinero'], [], [], ['nivel', 'gobierno'], ['hueso'], [],
#  [], ['ánimo', 'transformación'], ['cambio', 'deber'], [],
#  ['modos', 'gracia', 'monto', 'médico', 'preocupación'], ['lamebota'],
#  ['voto', 'frangie', 'ciudadanía', 'cosa', 'corruptela'], [], [], ['tema'], [],
#  [], [], ['pelagato', 'chayote', 'yolanda'], [],
#  ['conferencia', 'prensa', 'administración', 'gobierno'], ['chayote'],
#  ['dispendio', 'millonario'],
#  ['posibilidad', 'año', 'totalidad', 'distrito', 'municipio'],
#  ['regreso', 'gente', 'conciencia', 'regreso', 'corrupcion', 'prian'],
#  ['bandera'], [], [], [], ['dictadura', 'preferido', 'presidente'],
#  ['narco', 'corrupto'], ['cuerno'], [], [], ['teibolera'], [],
#  ['power', 'ranking', 'jalisco', 'lugar', 'alcalde'], [], [],
#  ['boot', 'favor', 'voto'], [], ['forma', 'pena'], ['cama'],
#  ['hombre', 'mujer', 'cárdena'],
#  ['persona', 'cambio', 'jalisco', 'presidente', 'ala', 'saludo'], ['opción'],
#  [], [], ['chemo', 'gente', 'barrio'], ['mensaje', 'sheinbaum'],
#  ['opción', 'jalisco'], [], [], [], ['morena'], ['voto'], ['1351'], [], [], [],
#  ['candidato', 'morena', 'jalisco', 'victoria'], [], ['opción'],
#  ['partido', 'credibilidad', 'comentarista'], [], ['gobernador', 'jalisco'], [],
#  [], [], [], [], [], ['chema'], ['deber', 'candidata', 'dedazo', 'policia'], [],
#  ['semana', 'política', 'show', 'dignidad'], ['opcion'], ['amigo', 'narco'],
#  ['pndejo', 'chayotero'],
#  ['chemo', 'opción', 'chema', 'pueblo', 'calidad', 'vida', 'ciudadano'],
#  ['cuerno', 'momia', 'jajajaja'], ['canijo', 'mc', 'candidato'], ['análisis'],
#  ['comentario', 'puntero', 'bot'], ['líder'], ['liderazgo', 'amor'], ['cambio'],
#  [], ['cambio', 'mano'], ['proceso'], [], ['varón', 'cama', 'caro'],
#  ['semana', 'liderazgo', 'amor', 'domingo'], ['medicina', 'tierra'], [],
#  ['jalisco', 'diferenciaclar'], [], ['chema'], ['chayote', 'alta'], [],
#  ['chema', 'gallo'], ['texto'], [], ['análisis', 'sesgo', 'chayote', 'ine'],
#  ['cárdena'], ['flor'], [], [], ['daño'], ['chema'], ['nachito', 'suerte'], [],
#  ['conocimiento', 'chemo'], ['nacho', 'ooh'], ['cálmate', 'cargo', 'ancia'], [],
#  ['ves'], ['cardena'], ['puebla', 'deber'], [],
#  ['dr', 'tienado', 'dinero', 'campaña', 'alcadia', 'llenar', 'propaganda'],
#  ['olovooooorgo'], [], ['julio', 'primo', 'mier', 'equipo'], ['ruta'],
#  ['negocio'], ['ruta'], [], ['ine', 'conque'], ['chinches'],
#  ['chema', 'gobernador'], ['gobernador'], [], ['pena'],
#  ['julio', 'primo', 'pie', 'amlo', 'prd', 'recurso', 'campaña'], [],
#  ['julio', 'primo', 'barboza'], [], ['lic'], ['detalle'],
#  ['negocio', 'fentanilo'], ['narcopolicía'], [], [], ['cinturón'],
#  ['alianza', 'alianza', 'candidata'], [], ['oir'], ['jer'], [], [], ['dato'],
#  [], ['representante', 'raíz', 'trayectoria', 'base'], ['apoyo'], [], [],
#  ['jarocha', 'madre'], ['partido', 'embajador', 'año'], [],
#  ['encuesta', 'interior', 'morena'], [], ['mujer'], ['chema', 'duda'], [], [],
#  ['varón', 'tabasco', 'esposa', 'salchicha'], [], [],
#  ['cobarde', 'secuestrado', 'silencio', 'secta', 'morena', 'asco'],
#  ['ecuación'], ['respuesta', 'jalisco'],
#  ['ine', 'orden', 'deber', 'mujer', 'facultad', 'echo', 'democracia', 'pueblo',
#   'deber', 'género', 'política', 'género', 'capacidad', 'liderazgo', 'hombre',
#   'mujer'],
#  [], [], ['evento', 'líder', 'metro', 'líder'], ['opción'],
#  ['deseir', 'piso', 'berrinche', 'niño', 'supermercado', 'busca', 'dulce',
#   'fuerza', 'ine'],
#  ['mira'], [],
#  ['gobernador', 'panista', 'morenista', 'traición', 'morena', 'coahuila'],
#  ['deber', 'presidenta'], ['respuesta'], [],
#  ['tesis', 'abogada', 'copia', 'vergüenza', 'favor', 'leerte'], [],
#  ['prestigio'], ['osea', 'presidenta', 'chayote', 'fuerza', 'zapato'],
#  ['aprendiz', 'policía', 'mayoría'], ['criterio'],
#  ['tiempo', 'mujer', 'jalisco'], [], [], ['puente', 'plata'],
#  ['amañado', 'comentario', 'mayoría', 'resultado', 'modos', 'voto',
#   'comentario'],
#  ['respuesta'], [], ['transformación'], [], ['chema'],
#  ['cariño', 'agradecimiento', 'empresa'], [], [], ['voto', 'cárdena', 'ruta'],
#  ['candidato', 'candidata', 'gubernatura', 'morena', 'cárdena'], ['jajaja'], [],
#  ['señora', 'chiste'], ['seguro', 'anormal'], [], ['lord', 'eschaira'], [], [],
#  ['felicidad', 'dinero', 'erario', 'hipocresía'], [], ['corrupto'],
#  ['candidato'], ['honor'], ['negocio', 'perdón', 'repetición'],
#  ['rémora', 'coneate'], ['chapulín', 'jalisco'], ['par', 'lacra'], [],
#  ['sector'], ['jalisco'], ['hora', 'date'], ['jalsico'], [], [],
#  ['muestra', 'cariño', 'palabra', 'aliento'], ['asiento', 'gobernador'],
#  ['bello', 'imagen'], [], ['par', 'corrupto'], [], [],
#  ['comentario', 'negociazo', 'marrano', 'verficadora', 'multa', 'goleada'],
#  ['agua'], ['año', 'campaña'], ['seguro'], ['paso'], ['exacto'], [], [],
#  ['sujeto', 'candidato', 'gobernador', 'sospecha', 'negocio', 'medicina'],
#  ['gobernador'], ['amiga', 'mujer', 'responsabilidad', 'dra'],
#  ['claudia', 'deber', 'paso', 'candidato', 'gobernador', 'mc', 'candidato',
#   'nexo', 'foto', 'cárcel', 'venta', 'medicina'],
#  [], ['jalisco', 'apoyo', 'doctora', 'doctor'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'], [], ['fuerza'],
#  ['equipo', 'transformación', 'jalisco'], [], ['territorio'], [],
#  ['nivel', 'gobierno'], ['hueso'], [], [], ['ánimo', 'transformación'],
#  ['cambio', 'deber'], ['modos', 'gracia', 'monto', 'médico', 'preocupación'],
#  ['lamebota'], ['voto', 'frangie', 'ciudadanía', 'cosa', 'corruptela'], [],
#  ['tema'], [], [], ['pelagato', 'chayote', 'yolanda'], [],
#  ['conferencia', 'prensa', 'administración', 'gobierno'], ['chayote'],
#  ['dispendio', 'millonario'],
#  ['posibilidad', 'año', 'totalidad', 'distrito', 'municipio'],
#  ['regreso', 'gente', 'conciencia', 'regreso', 'corrupcion', 'prian'],
#  ['bandera'], [], ['2549'], [], ['dictadura', 'preferido', 'presidente'], [],
#  ['power', 'ranking', 'jalisco', 'lugar', 'alcalde'], [], [],
#  ['boot', 'favor', 'voto'], [], ['forma', 'pena'], ['cama'],
#  ['hombre', 'mujer', 'cárdena'],
#  ['persona', 'cambio', 'jalisco', 'presidente', 'ala', 'saludo'], ['opción'],
#  ['7704'], [], ['chemo', 'gente', 'barrio'], ['mensaje', 'sheinbaum'],
#  ['opción', 'jalisco'], [], [], ['morena'], ['voto'], [], [], [],
#  ['candidato', 'morena', 'jalisco', 'victoria'], [], ['opción'],
#  ['partido', 'credibilidad', 'comentarista'], [], ['gobernador', 'jalisco'], [],
#  [], [], [], [], ['chema'], ['deber', 'candidata', 'dedazo', 'policia'],
#  ['semana', 'política', 'show', 'dignidad'], ['opcion'], ['amigo', 'narco'],
#  ['pndejo', 'chayotero'],
#  ['chemo', 'opción', 'chema', 'pueblo', 'calidad', 'vida', 'ciudadano'],
#  ['cuerno', 'momia', 'jajajaja'], ['canijo', 'mc', 'candidato'], ['análisis'],
#  ['comentario', 'puntero', 'bot'], ['líder'], ['liderazgo', 'amor'], ['cambio'],
#  ['cambio', 'mano'], ['proceso'], [], ['varón', 'cama', 'caro'],
#  ['semana', 'liderazgo', 'amor', 'domingo'], ['medicina', 'tierra'],
#  ['jalisco', 'diferenciaclar'], [], ['chema'], ['chayote', 'alta'], [],
#  ['chema', 'gallo'], ['texto'], [], ['análisis', 'sesgo', 'chayote', 'ine'],
#  ['cárdena'], ['flor'], [], [], [], ['daño'], ['chema'], ['nachito', 'suerte'],
#  ['conocimiento', 'chemo'], ['nacho', 'ooh'], ['cálmate', 'cargo', 'ancia'], [],
#  ['ves'], ['cardena'], ['puebla', 'deber'], [],
#  ['dr', 'tienado', 'dinero', 'campaña', 'alcadia', 'llenar', 'propaganda'],
#  ['olovooooorgo'], ['julio', 'primo', 'mier', 'equipo'], ['ruta'], ['negocio'],
#  ['ruta'], [], ['ine', 'conque'], ['chinches'], ['chema', 'gobernador'],
#  ['gobernador'], [], ['pena'],
#  ['julio', 'primo', 'pie', 'amlo', 'prd', 'recurso', 'campaña'], [],
#  ['julio', 'primo', 'barboza'], ['lic'], ['detalle'], ['negocio', 'fentanilo'],
#  ['narcopolicía'], [], ['cinturón'], ['alianza', 'alianza', 'candidata'],
#  ['oir'], ['jer'], [], [], ['dato'], [],
#  ['representante', 'raíz', 'trayectoria', 'base'], ['apoyo'], [], [],
#  ['jarocha', 'madre'], ['partido', 'embajador', 'año'], [],
#  ['encuesta', 'interior', 'morena'], [], ['mujer'], ['chema', 'duda'], [], [],
#  ['varón', 'tabasco', 'esposa', 'salchicha'], [], [],
#  ['cobarde', 'secuestrado', 'silencio', 'secta', 'morena', 'asco'],
#  ['ecuación'], ['respuesta', 'jalisco'],
#  ['ine', 'orden', 'deber', 'mujer', 'facultad', 'echo', 'democracia', 'pueblo',
#   'deber', 'género', 'política', 'género', 'capacidad', 'liderazgo', 'hombre',
#   'mujer'],
#  [], ['evento', 'líder', 'metro', 'líder'], ['opción'],
#  ['deseir', 'piso', 'berrinche', 'niño', 'supermercado', 'busca', 'dulce',
#   'fuerza', 'ine'],
#  ['mira'],
#  ['gobernador', 'panista', 'morenista', 'traición', 'morena', 'coahuila'],
#  ['deber', 'presidenta'], ['respuesta'], [],
#  ['tesis', 'abogada', 'copia', 'vergüenza', 'favor', 'leerte'], ['mira'],
#  ['prestigio'], ['osea', 'presidenta', 'chayote', 'fuerza', 'zapato'], [],
#  ['aprendiz', 'policía', 'mayoría'], ['criterio'],
#  ['tiempo', 'mujer', 'jalisco'], [], ['puente', 'plata'],
#  ['amañado', 'comentario', 'mayoría', 'resultado', 'modos', 'voto',
#   'comentario'],
#  ['respuesta'], ['transformación'], [], ['chema'],
#  ['cariño', 'agradecimiento', 'empresa'], [], [], ['voto', 'cárdena', 'ruta'],
#  ['candidato', 'candidata', 'gubernatura', 'morena', 'cárdena'], ['jajaja'],
#  ['1171'], ['señora', 'chiste'], ['seguro', 'anormal'], [],
#  ['lord', 'eschaira'], [], ['felicidad', 'dinero', 'erario', 'hipocresía'], [],
#  ['corrupto'], ['candidato'], ['honor'], ['negocio', 'perdón', 'repetición'],
#  ['rémora', 'coneate'], ['chapulín', 'jalisco'], ['par', 'lacra'], ['1110'],
#  ['sector'], ['jalisco'], ['hora', 'date'], ['jalsico'], [], [],
#  ['muestra', 'cariño', 'palabra', 'aliento'], ['asiento', 'gobernador'],
#  ['bello', 'imagen'], ['par', 'corrupto'], [], [],
#  ['comentario', 'negociazo', 'marrano', 'verficadora', 'multa', 'goleada'],
#  ['agua'], ['año', 'campaña'], ['seguro'], ['paso'], ['exacto'], [], [],
#  ['sujeto', 'candidato', 'gobernador', 'sospecha', 'negocio', 'medicina'],
#  ['gobernador'], ['amiga', 'mujer', 'responsabilidad', 'dra'],
#  ['claudia', 'deber', 'paso', 'candidato', 'gobernador', 'mc', 'candidato',
#   'nexo', 'foto', 'cárcel', 'venta', 'medicina'],
#  [], ['jalisco', 'apoyo', 'doctora', 'doctor'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'],
#  ['tratro', 'jugaste', 'corrupto', 'traidor', 'karma', 'lugar'], [], ['fuerza'],
#  ['equipo', 'transformación', 'jalisco'], [], ['territorio'], [],
#  ['jalisco', 'gente', 'maltrato'], ['chinch'], [],
#  ['conocimiento', 'duda', 'inseguridad', 'problemática'],
#  ['asesinato', 'narco'], [], ['falta', 'bax'],
#  ['rincón', 'orgullo', 'oficio', 'vocación', 'jalisciens', 'problema', 'habrás',
#   'gobernador', 'abrazo'],
#  ['trabajo', 'experiencia'],
#  ['político', 'pena', 'dinero', 'gente', 'represente', 'proyecto', 'amlo',
#   'diputación', 'candidatura', 'presidencia', 'gobernador'],
#  ['esposa', 'hija', 'bendición', 'rincón', 'jalisco', 'comunidad', 'amiga',
#   'amigo', 'regalo'],
#  ['fortuna'], [],
#  ['doctor', 'acarreo', 'manipulación', 'funcionario', 'gobierno', 'trabajo',
#   'paradójico', 'administración', 'morenista'],
#  ['honor', 'doctor'],
#  ['sirviendote', 'comunidad', 'gracias', 'dinero', 'pueblo', 'sobreprecio',
#   'medicina', 'imss'],
#  ['deseo', 'gracia', 'preocupación'],
#  ['gusto', 'momento', 'vecino', 'tonalá', 'deseo', 'comités', 'defensa',
#   'transformación', 'jalisco', 'jalisco'],
#  ['medicamento', 'mesa', 'año', 'década', 'obsesión'],
#  ['denuncia', 'amparo', 'despilfarro', 'cintura', 'cantero', 'lelus'],
#  ['señor'], ['honestidad', 'septiembre'], [],
#  ['gente', 'campaña', 'candidato', 'elección', 'equipo', 'pendejo', 'traidor'],
#  ['ok', 'lista', 'elección'],
#  ['democracia', 'lugar', 'jallisco', 'crimen', 'deber', 'pueblo', 'aceptación',
#   'gobernarno', 'horizontalidad', 'ego', 'capital'],
#  ['candidato', 'jalisco'], ['pueblo'],
#  ['comentario', 'red', 'gente', 'recorrido', 'camino', 'vida', 'compromiso'],
#  [], ['mensaje'], ['gobernador', 'jalisco'], [], [], ['servicio', 'cárcel'],
#  ['vida', 'comunidad'], ['encuesta'], [],
#  ['jajaja', 'maquillaje', 'edición', 'evento', 'reflector', 'sueter', 'cuello',
#   'tortuga'],
#  ['comunidad', 'perdón', 'medicamento', 'tratamiento', 'cáncer', 'gente',
#   'praton', 'ayuda'],
#  ['mujer', 'libertad', 'grito', 'cárcel', 'narges', 'activista', 'premio',
#   'paz', 'mujer', 'víctima', 'violencia', 'indiferencia', 'gobierno',
#   'clamor'],
#  [], ['falla', 'coraje'], [],
#  ['ratero', 'morena', 'jalisco', 'tipo', 'alcalde'], ['quitar'], [],
#  ['guanjo', 'cochinada'], [], ['menso'], ['barda'], ['mandoel', 'año', 'talv'],
#  ['vida', 'comunidad', 'chiste'],
#  ['distrito', 'jalisco', 'impunidad', 'naranja', 'dinero'], [],
#  ['vida', 'comunidad', 'distrito', 'visita', 'trabajo', 'mano', 'joven',
#   'líder', 'carencia', 'conciencia', 'corazón'],
#  [], ['jajaja', 'pendejo'], [], [], [],
#  ['dr', 'gobernador', 'jalisco', 'apoyo', 'dr'], ['edificio', 'propiedad'], [],
#  ['gobernador', 'jalisco'], ['cambio', 'dr', 'apoyo'], ['dr'], ['mano', 'dr'],
#  ['cosa', 'lame', 'huevo', 'jajajaaja'], ['corrupto'],
#  ['candidato', 'partido', 'cosa', 'aspirante', 'pensión', 'oro', 'candidato',
#   'gobernador'],
#  ['mujer', 'jalisco', 'dignidad', 'sueño', 'realidad'], [],
#  ['candidato', 'morena', 'jalisco', 'interés', 'peña'], ['cuéntano', 'perro'],
#  ['2012', '2015', '2018', '2021'], ['2012', 'año'],
#  ['pendejo', 'victoria', 'pelón', 'alfaroi', 'lemus', 'banda', 'lemus', 'kgada',
#   'candidato', 'morén'],
#  [], ['propiedad'], ['transa', 'empresa', 'gracia', 'preocupación'], [],
#  ['mamada', 'jalisco', 'oportunidad'],
#  ['año', 'interés', 'pie', 'lucha', 'hueso', 'aspiración', 'motor',
#   'desesperanza'],
#  [], ['duda', 'pueblo', 'jalisco'], ['candidato'], [], [], ['vocero'], [], [],
#  [], ['suela', 'pueblo'], ['edificio', 'desmadre', 'amigo', 'narco'],
#  ['objetivo', 'coordinador', 'defensa', 'transformación', 'jalisco'], ['apoyo'],
#  ['encuesta', 'partido', 'ley', 'candidato', 'puesto', 'elección', 'señor'],
#  ['gente', 'gracias', 'cercanía', 'dr'],
#  ['honor', 'diálogo', 'militante', 'simpatizante', 'morena', 'teuchitlán',
#   'reunión', 'compromiso', 'transformación', 'motivo', 'comités', 'defensa'],
#  ['gobernador', 'jalisco'], ['miércoles'], ['mujer', 'garra', 'debenso'],
#  ['doña', 'asesinato', 'lobby'], ['matador'], ['ojo', 'edificio'], [],
#  ['hombre', 'edificio'], ['asesinato', 'hombre', 'edificio'], ['matador'],
#  ['respuesta'], ['6337'], ['respuesta'], ['respuesta'], ['edificio'], [], [],
#  ['sobreprecio'], ['perseverancia', 'trabajo', 'sueño'], ['mc'],
#  ['dinero', 'honestidad'], ['presidente', 'militar', 'culpa', 'estudiante'],
#  ['morena', 'piedra', 'mano'], [],
#  ['poniente', 'ciudad', 'avenida', 'zalate', 'pandilla', 'necesitar'],
#  ['paz', 'prosperidad', 'vida'], ['administración', 'compitio'], ['carisma'],
#  ['nombramiento', 'chayote', 'oro'],
#  ['mensaje', 'lona', 'apoyo', 'persona', 'duda'], ['serio'], ['sur'], [],
#  ['culo'], ['medicamento', 'sobreprecio', 'honestidad'], ['cardena'], [],
#  ['burro'], ['lemus', 'informe', 'campaña', 'logo'],
#  ['proceso', 'rumbo', '2024', 'preferencia', 'mc'],
#  ['cdmx', 'judío', 'línea', 'falta', 'mantenimiento', 'metro', 'covid'],
#  ['doctor', 'paga'], ['manipulación', 'información', 'consecuencia'],
#  ['seguridad'], ['jalisco'], [], ['honesto', 'integro', 'palabra'],
#  ['omeprazol', 'precio'], ['vera'], [], ['capital'], ['internet'],
#  ['generación', 'publicidad'],
#  ['tarea', 'solución', 'problema', 'municipio', 'forma'], [],
#  ['barda', 'estrategia'], ['justificación', 'moreno', 'ero'],
#  ['jjajajaja', 'neta'], ['tantostanto', 'tweet'],
#  ['lomelí', 'jajajaja', 'jajajaja'], [], [], ['morena'], [], [], [],
#  ['candidato', 'morena', 'perdido', 'partido'],
#  ['estilo', 'claudia', 'morén', 'jajaja'],
#  ['carlito', 'pueblo', 'diario', 'inteligencia'], ['doc', 'jalisciens', 'mc'],
#  ['che', 'rata', 'cuello', 'dinero', 'favor', 'jefa'], ['jajajajo', 'jajaja'],
#  ['transformador', 'cuarto', 'ridículo', 'compañero', 'secta', 'tiempo'], [],
#  ['cargo'], ['octubre', '2011'], ['papá', 'checo'],
#  ['propuesta', 'dr', 'idea', 'demuestre'], [], ['alliens'],
#  ['discurso', 'sheinbaum', 'pueblo'], [], ['campaña'], ['jajaja'],
#  ['denuncia', 'cobro', 'secretario', 'pablo', 'eldirector', 'atención'], [],
#  ['persona', 'candidatura'], [],
#  ['movimiento', 'hermano', 'morena', 'político', 'órden', 'viejito'], ['gente'],
#  ['morena', 'editorial', 'proveedor', 'bolsa'],
#  ['inversor', 'empresario', 'frase', 'honestidad', 'regalo', 'esper', 'persona',
#   'duda', 'vida', 'integridad', 'base', 'sociedad', 'arranque', 'semana'],
#  [], ['df', 'amigo', 'millón', 'enseñanza', 'amo'], ['política', 'político'],
#  ['jajajajajajajajajajajajajajajajajajajajaja'], [],
#  ['hijo', 'pu74', 'madre', 'jajaja'], ['nomás', 'pendiente'],
#  ['jalisco', 'encuesta', 'criterio', 'candidato', 'gubernatura'], [], [],
#  ['candidatura', 'dinero', 'campaña', 'claudia'], [], ['gente'],
#  ['campaña', 'doctor'], [],
#  ['fuiste', 'apuro', 'ipejal', 'aspecto', 'medicina'],
#  ['morena', 'nombre', 'consejo', 'partido'], ['lugar', 'cargo'],
#  ['amigo', 'narco'], [], ['candidato', 'favor'], ['lacra'], ['menso', 'barda'],
#  ['tío', 'celular'], ['ridiculo', 'lona'], ['pincher'],
#  ['jajajajajajaja', 'amor', 'persona', 'gente'], ['jajajajaja'], [], [],
#  ['ley'],
#  ['momento', 'proveedor', 'precursor', 'cartel', 'amigo', 'humanista',
#   'gobernador'],
#  [], ['rata'], ['jajajajajajaja', 'vida', 'corrupción', 'ilegalidad'],
#  ['partido', 'causa', 'pueblo', 'jalisco', 'oportunidad', 'pacto', 'alfaro'],
#  ['jajaja', 'morenaco'], ['ciudadano', 'proselitismo'], ['fracasa', 'proyecto'],
#  ['tipo'], [], ['corrupto', 'jaja', 'carlito', 'recurso', 'empresa', 'familia'],
#  ['millón', 'fan'], ['pinche'], [],
#  ['morena', 'cdmx', 'jalisco', 'barda', 'aspirante'],
#  ['ciudad', 'nombre', 'cjng'],
#  ['negocio', 'política', 'excepción', 'caso', 'contrato', 'venta',
#   'medicamento', 'sobreprecio', 'gasto', 'campaña', 'mano', 'tiempo',
#   'campaña'],
#  ['agua'], ['presidente', 'sueldo', 'policíasque'], ['apoyo', 'gratuito'],
#  ['dr', 'apoyo', 'persona', 'jajajajajajaja', 'tradición', 'mexicano', 'dinero',
#   'amor', 'ratero', 'lambiscón', 'dinero', 'maroma', 'elección'],
#  ['unidad'], [],
#  ['amlo', 'artillería', 'co', 'gobierno', 'morén', 'guerrero', 'infórmense',
#   'vocero', 'morena'],
#  ['político', 'tiempo', 'fecha', 'barda', 'nombre'], [], [], ['hdspm'],
#  ['impuesto', 'candidato', 'mc', 'alianza'], [], ['político', 'mentira'], [],
#  ['chemazo', 'apoyo', 'persona', 'sueldo', 'jajaja'], ['morena', 'tweet'],
#  ['perro'], [], [], [], ['ánimo'], ['mano'], ['post', 'dinero', 'basura']]

# %%
import seaborn as sns 

lengths =  [len(x) for x in docs]
# Build the histogram, distribution of lemmas in the texts
sns.histplot(lengths)
# Out:
# <Axes: ylabel='Count'>

# %%
from gensim.models import CoherenceModel

# Defining dictionary and corpus with Gensim
dictionary = corpora.Dictionary(docs)
dictionary.add_documents(colocaciones)  # Agregar n-gramas al diccionario

corpus = [dictionary.doc2bow(text) for text in docs]

def calculate_coherence(dictionary, corpus, docs, start, stop):
    scores = []
    for topics in range(start, stop):

        # defining the model
        lda_model = LdaModel(corpus, id2word=dictionary, num_topics=20, alpha='auto', eval_every=5)

        # U_mass coherence score
        cm_u_mass = CoherenceModel(model=lda_model, corpus=corpus, dictionary=dictionary, coherence='u_mass')
        u_mass_coherence = cm_u_mass.get_coherence()

        # C_v coherence score
        cm_c_v = CoherenceModel(model=lda_model, texts=docs, dictionary=dictionary, coherence='c_v')
        c_v_coherence = cm_c_v.get_coherence()

        values = [topics, u_mass_coherence, c_v_coherence]

        scores.append(values)

    return scores

# calculare scores
scores = calculate_coherence(dictionary, corpus, docs, 5, 20)
scores
# Out:
# [[5, -18.18036016556624, 0.5421405257028533],
#  [6, -18.631380143528347, 0.5684842195697397],
#  [7, -18.79845024449278, 0.580377726001851],
#  [8, -18.456556191552078, 0.5577916383449797],
#  [9, -18.646146491072706, 0.561538776964362],
#  [10, -18.570605241308307, 0.553157836883263],
#  [11, -19.10733835008353, 0.5888223707660435],
#  [12, -18.884656252375457, 0.5864962069948719],
#  [13, -18.65902935600577, 0.5610693783431018],
#  [14, -18.848761186322083, 0.5790505407379156],
#  [15, -18.604098991605902, 0.5645406184292134],
#  [16, -18.659566231309448, 0.5715244196488464],
#  [17, -18.618481767290596, 0.5670249628170213],
#  [18, -18.596520902523785, 0.576311958175105],
#  [19, -18.385956317736124, 0.5698558003411061]]

# %%
# scores to df
df = pd.DataFrame(scores, columns = ['number_of_topics','u_mass_coherence','c_v_coherence'])

# tidying the df
df = df.melt(id_vars=['number_of_topics'], value_vars=['u_mass_coherence','c_v_coherence'])

# Plotting u_mass_coherence
sns.lineplot(data=df.loc[df['variable'] == 'u_mass_coherence'], x="number_of_topics", y="value").set_title('u_mass coherence')
# Out:
# Text(0.5, 1.0, 'u_mass coherence')

# %%
# Plotting c_v_coherence
sns.lineplot(data=df.loc[df['variable'] == 'c_v_coherence'], x="number_of_topics", y="value").set_title('c_v coherence')
# Out:
# Text(0.5, 1.0, 'c_v coherence')

# %%
lda_model = LdaModel(corpus, id2word=dictionary, num_topics=12, alpha='auto', eval_every=5, passes=15)

# print topics
topics = lda_model.print_topics(-1)

# Mostrar los temas y sus palabras clave
for topic in topics:
    print(topic)
# Out:
# (0, '0.041*"opción" + 0.032*"semana" + 0.030*"ruta" + 0.028*"liderazgo" + 0.023*"jalisco" + 0.018*"política" + 0.018*"primo" + 0.018*"julio" + 0.018*"amor" + 0.014*"proyecto"')
# (1, '0.032*"encuesta" + 0.024*"morena" + 0.024*"morén" + 0.016*"jalisco" + 0.014*"interior" + 0.014*"jajaja" + 0.014*"flor" + 0.014*"comunidad" + 0.014*"criterio" + 0.010*"pelón"')
# (2, '0.044*"cárdena" + 0.037*"apoyo" + 0.035*"gobernador" + 0.031*"candidato" + 0.023*"mujer" + 0.016*"exacto" + 0.016*"hombre" + 0.016*"gubernatura" + 0.014*"voto" + 0.012*"empresa"')
# (3, '0.046*"gente" + 0.026*"chemo" + 0.025*"favor" + 0.021*"agua" + 0.021*"vida" + 0.017*"regreso" + 0.017*"territorio" + 0.013*"copia" + 0.013*"cardena" + 0.013*"basura"')
# (4, '0.066*"candidato" + 0.043*"chema" + 0.021*"mc" + 0.019*"gobernador" + 0.019*"claudia" + 0.018*"dinero" + 0.016*"cama" + 0.016*"comentario" + 0.016*"varón" + 0.016*"partido"')
# (5, '0.106*"jalisco" + 0.024*"morena" + 0.018*"gobernador" + 0.018*"gobierno" + 0.018*"rata" + 0.018*"alianza" + 0.018*"gente" + 0.015*"mujer" + 0.015*"seguro" + 0.011*"transformación"')
# (6, '0.063*"corrupto" + 0.060*"morena" + 0.037*"lugar" + 0.026*"amigo" + 0.026*"narco" + 0.026*"líder" + 0.023*"traidor" + 0.023*"karma" + 0.023*"jugaste" + 0.023*"tratro"')
# (7, '0.060*"doctor" + 0.041*"dr" + 0.028*"jalisco" + 0.025*"persona" + 0.020*"apoyo" + 0.018*"señor" + 0.018*"gente" + 0.014*"elección" + 0.014*"presidente" + 0.014*"saludo"')
# (8, '0.037*"respuesta" + 0.030*"chayote" + 0.024*"jalisco" + 0.022*"morena" + 0.022*"ine" + 0.022*"fuerza" + 0.015*"análisis" + 0.015*"partido" + 0.015*"pueblo" + 0.012*"candidato"')
# (9, '0.042*"deber" + 0.038*"mujer" + 0.021*"puntero" + 0.017*"encuesta" + 0.017*"género" + 0.017*"dedazo" + 0.017*"partido" + 0.016*"par" + 0.013*"año" + 0.013*"jajajajajajaja"')
# (10, '0.046*"campaña" + 0.046*"año" + 0.025*"cambio" + 0.021*"transformación" + 0.013*"dr" + 0.013*"deber" + 0.013*"lobby" + 0.013*"trabajo" + 0.013*"ánimo" + 0.013*"mano"')
# (11, '0.022*"mano" + 0.022*"jajaja" + 0.022*"honor" + 0.018*"morena" + 0.018*"pena" + 0.013*"recurso" + 0.013*"chayote" + 0.013*"historia" + 0.009*"pueblo" + 0.009*"corrupto"')

# %%
import pyLDAvis
import pyLDAvis.gensim

pyLDAvis.enable_notebook()
viz = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
viz
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.113381 -0.051660       1        1  11.147226
# 7     -0.137646 -0.007884       2        1   9.422179
# 5     -0.028747 -0.031288       3        1   9.244390
# 8     -0.005929  0.011331       4        1   8.885298
# 6      0.179474 -0.174595       5        1   8.853352
# 2     -0.052454 -0.097227       6        1   8.252664
# 10     0.070468  0.123569       7        1   7.818720
# 9      0.040888  0.130032       8        1   7.744546
# 3     -0.091970 -0.023179       9        1   7.664102
# 11     0.121709  0.014124      10        1   7.388165
# 0      0.006139  0.120003      11        1   6.814445
# 1      0.011451 -0.013225      12        1   6.764915, topic_info=          Term       Freq      Total Category  logprob  loglift
# 46     jalisco  43.000000  43.000000  Default  30.0000  30.0000
# 44   candidato  27.000000  27.000000  Default  29.0000  29.0000
# 5     corrupto  14.000000  14.000000  Default  28.0000  28.0000
# 3       doctor  13.000000  13.000000  Default  27.0000  27.0000
# 28      morena  30.000000  30.000000  Default  26.0000  26.0000
# ..         ...        ...        ...      ...      ...      ...
# 162    claudia   1.448643   8.793294  Topic12  -4.6335   0.8901
# 46     jalisco   2.311371  43.519431  Topic12  -4.1663  -0.2419
# 44   candidato   1.448643  27.292455  Topic12  -4.6335  -0.2426
# 61       gente   0.860911  17.286670  Topic12  -5.1539  -0.3063
# 142    campaña   0.754567  11.372850  Topic12  -5.2858  -0.0194
#
# [581 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 692      12  0.708544     2015
# 693      12  0.708544     2018
# 694      12  0.708544     2021
# 35        2  0.688568     2024
# 35        3  0.344284     2024
# ...     ...       ...      ...
# 435       4  0.924674  yolanda
# 728      11  0.716417   zalate
# 550       4  0.924682   zapato
# 332       7  0.701270      zar
# 424       7  0.702733    ánimo
#
# [749 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 8, 6, 9, 7, 3, 11, 10, 4, 12, 1, 2])

# %%
import networkx as nx

# Crear un grafo de red
G = nx.Graph()

# Procesar los tópicos y sus palabras clave para identificar asociaciones
for topic_id, topic_words in topics:
    # Dividir las palabras clave en términos individuales
    terms = [term.split('*')[1].strip('"') for term in topic_words.split(' + ')]
    
    # Agregar una arista entre todos los términos del tópico
    for i in range(len(terms)):
        for j in range(i + 1, len(terms)):
            term1, term2 = terms[i], terms[j]
            G.add_edge(term1, term2, topic=topic_id)

# Dibujar el gráfico de red
pos = nx.spring_layout(G, k=0.3, iterations=50)
plt.figure(figsize=(10, 8))
nx.draw(G, pos, with_labels=True, font_size=10, node_size=3000, node_color='maroon', font_color='white')

# Mostrar el gráfico de red
plt.title('Asociación de Términos entre Tópicos')
# Guardar la figura como una imagen
plt.savefig('topicos.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
# Función para obtener solo las palabras de un texto
def obtener_palabras(texto):
    palabras = re.findall(r'"([^"]*)"', texto)
    return palabras

# Aplicar la función a cada elemento del arreglo
solo_palabras = [(indice, obtener_palabras(texto)) for indice, texto in topics]

topicos = pd.DataFrame(solo_palabras,  columns=['No. Topico', 'Palabras Clave'])

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import dash_table
import dash_table



app = dash.Dash(__name__)

app.layout = html.Div([
    dash_table.DataTable(
        id='table',
        columns=[{"name": col, "id": col} for col in df.columns],
        data=df.to_dict('records'),
        editable=True,
        export_format='csv',  # Agrega esta opción para exportar los datos
        style_table={'overflowX': 'scroll'},  # Permite desplazarse horizontalmente
    ),
])


if __name__ == '__main__':
    app.run(jupyter_mode="external")
# Out:
# Dash app running on http://127.0.0.1:8050/
